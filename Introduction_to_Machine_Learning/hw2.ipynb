# %% [markdown]
# # **Homework 2-1 Phoneme Classification**
#
# * Slides: https://speech.ee.ntu.edu.tw/~hylee/ml/ml2021-course-data/hw/HW02/HW02.pdf
# * Video (Chinese): https://youtu.be/PdjXnQbu2zo
# * Video (English): https://youtu.be/ESRr-VCykBs

# %% [markdown]
# ## The DARPA TIMIT Acoustic-Phonetic Continuous Speech Corpus (TIMIT)
# The TIMIT corpus of reading speech has been designed to provide speech data for the acquisition of acoustic-phonetic knowledge and for the development and evaluation of automatic speech recognition systems.
#
# This homework is a multiclass classification task,
# we are going to train a deep neural network classifier to predict the phonemes for each frame from the speech corpus TIMIT.
#
# link: https://academictorrents.com/details/34e2b78745138186976cbc27939b1b34d18bd5b3

# %% [markdown]
# ## Download Data
# Download data from google drive, then unzip it.
#
# You should have `timit_11/train_11.npy`, `timit_11/train_label_11.npy`, and `timit_11/test_11.npy` after running this block.<br><br>
# `timit_11/`
# - `train_11.npy`: training data<br>
# - `train_label_11.npy`: training label<br>
# - `test_11.npy`:  testing data<br><br>
#
# **notes: if the google drive link is dead, you can download the data directly from Kaggle and upload it to the workspace**

# %%
# !nvidia-smi
# Out:
# Fri Mar 17 02:54:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA A100-SXM...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    54W / 400W |      0MiB / 40960MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown --id '1iDmtJ8vg-SF8dC0r0AoOg4n5UdVOj9To' --output data.zip
# !unzip data.zip
# !ls
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.9/dist-packages (4.4.0)
# Collecting gdown
#   Downloading gdown-4.6.4-py3-none-any.whl (14 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from gdown) (4.65.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from gdown) (3.9.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown) (4.9.3)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.9/dist-packages (from gdown) (2.25.1)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown) (2.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.26.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: gdown
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# Successfully installed gdown-4.6.4
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1iDmtJ8vg-SF8dC0r0AoOg4n5UdVOj9To
# To: /content/data.zip
# 100% 272M/272M [00:06<00:00, 44.5MB/s]
# Archive:  data.zip
#    creating: timit_11/
#   inflating: __MACOSX/._timit_11
#   inflating: timit_11/train_11.npy
#   inflating: __MACOSX/timit_11/._train_11.npy
#   inflating: timit_11/test_11.npy
#   inflating: __MACOSX/timit_11/._test_11.npy
#   inflating: timit_11/train_label_11.npy
#   inflating: __MACOSX/timit_11/._train_label_11.npy
# data.zip  __MACOSX  sample_data  timit_11

# %% [markdown]
# ## Preparing Data
# Load the training and testing data from the `.npy` file (NumPy array).

# %%
import numpy as np

print('Loading data ...')

data_root='./timit_11/'
train = np.load(data_root + 'train_11.npy')
train_label = np.load(data_root + 'train_label_11.npy')
test = np.load(data_root + 'test_11.npy')

print('Size of training data: {}'.format(train.shape))
print('Size of testing data: {}'.format(test.shape))
# Out:
# Loading data ...
# Size of training data: (922449, 429)
# Size of testing data: (307483, 429)

# %% [markdown]
# ## Create Dataset

# %%
import torch
from torch.utils.data import Dataset

class TIMITDataset(Dataset):
    def __init__(self, X, y=None):
        self.data = torch.from_numpy(X).float()
        if y is not None:
            y = y.astype(np.int)
            self.label = torch.LongTensor(y)
        else:
            self.label = None

    def __getitem__(self, idx):
        if self.label is not None:
            return self.data[idx], self.label[idx]
        else:
            return self.data[idx]

    def __len__(self):
        return len(self.data)

# %% [markdown]
# Split the labeled data into a training set and a validation set, you can modify the variable `VAL_RATIO` to change the ratio of validation data.

# %%
VAL_RATIO = 0

percent = int(train.shape[0] * (1 - VAL_RATIO))
train_x, train_y, val_x, val_y = train[:percent], train_label[:percent], train[percent:], train_label[percent:]
print('Size of training set: {}'.format(train_x.shape))
print('Size of validation set: {}'.format(val_x.shape))
# Out:
# Size of training set: (922449, 429)
# Size of validation set: (0, 429)

# %% [markdown]
# Create a data loader from the dataset, feel free to tweak the variable `BATCH_SIZE` here.

# %%
BATCH_SIZE = 2048

from torch.utils.data import DataLoader

train_set = TIMITDataset(train_x, train_y)
val_set = TIMITDataset(val_x, val_y)
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True) #only shuffle the training data
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE, shuffle=False)
# Out:
# <ipython-input-4-f6af567917fe>:8: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = y.astype(np.int)

# %% [markdown]
# Cleanup the unneeded variables to save memory.<br>
#
# **notes: if you need to use these variables later, then you may remove this block or clean up unneeded variables later<br>the data size is quite huge, so be aware of memory usage in colab**

# %%
import gc

del train, train_label, train_x, train_y, val_x, val_y
gc.collect()
# Out:
# 0

# %% [markdown]
# ## Create Model

# %% [markdown]
# Define model architecture, you are encouraged to change and experiment with the model architecture.

# %%
import torch
import torch.nn as nn

class Classifier(nn.Module):
    def __init__(self):
        super(Classifier, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(429, 2048),
            nn.LeakyReLU(),
            nn.BatchNorm1d(2048),
            nn.Dropout(0.5),
            nn.Linear(2048, 2048),
            nn.LeakyReLU(),
            nn.BatchNorm1d(2048),
            nn.Dropout(0.5),
            nn.Linear(2048, 2048),
            nn.LeakyReLU(),
            nn.BatchNorm1d(2048),
            nn.Dropout(0.5),
            nn.Linear(2048, 1024),
            nn.LeakyReLU(),
            nn.BatchNorm1d(1024),
            nn.Dropout(0.5),
            nn.Linear(1024, 512),
            nn.LeakyReLU(),
            nn.BatchNorm1d(512),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.LeakyReLU(),
            nn.BatchNorm1d(256),
            nn.Dropout(0.5),
            nn.Linear(256, 39)
        )
        self.criterion = nn.CrossEntropyLoss()

    def forward(self, x):
        return self.net(x)

    def cal_loss(self, pred, target, l1):
      l1_regulation = torch.tensor(0.).to(device)
      for parameter in model.parameters():
        l1_regulation += torch.sum(torch.abs(parameter))
      return self.criterion(pred, target) + (l1 * l1_regulation)

# %% [markdown]
# ## Training

# %%
#check device
def get_device():
  return 'cuda' if torch.cuda.is_available() else 'cpu'

# %% [markdown]
# Fix random seeds for reproducibility.

# %%
# fix random seed
def same_seeds(seed):
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)  
    np.random.seed(seed)  
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# Feel free to change the training parameters here.

# %%
# fix random seed for reproducibility
same_seeds(0)

# get device 
device = get_device()
print(f'DEVICE: {device}')

# training parameters
num_epoch = 250               # number of training epoch
learning_rate = 0.0001       # learning rate
l2 = 1e-4
l1 = 1e-5

# the path where checkpoint saved
model_path = './model.ckpt'

# create model, define a loss function, and optimizer
model = Classifier().to(device)
criterion = nn.CrossEntropyLoss() 
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
# Out:
# DEVICE: cuda

# %%
# start training

best_acc = 0.0
for epoch in range(num_epoch):
    train_acc = 0.0
    train_loss = 0.0
    val_acc = 0.0
    val_loss = 0.0

    # training
    model.train() # set the model to training mode
    for i, data in enumerate(train_loader):
        inputs, labels = data
        inputs, labels = inputs.to(device), labels.to(device)
        optimizer.zero_grad() 
        outputs = model(inputs) 
        batch_loss = model.cal_loss(outputs, labels, l1=l1)
        #batch_loss = criterion(outputs, labels)
        _, train_pred = torch.max(outputs, 1) # get the index of the class with the highest probability
        batch_loss.backward() 
        optimizer.step() 

        train_acc += (train_pred.cpu() == labels.cpu()).sum().item()
        train_loss += batch_loss.item()

    # validation
    if len(val_set) > 0:
        model.eval() # set the model to evaluation mode
        with torch.no_grad():
            for i, data in enumerate(val_loader):
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)
                outputs = model(inputs)
                batch_loss = criterion(outputs, labels) 
                _, val_pred = torch.max(outputs, 1) 
            
                val_acc += (val_pred.cpu() == labels.cpu()).sum().item() # get the index of the class with the highest probability
                val_loss += batch_loss.item()

            print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f} | Val Acc: {:3.6f} loss: {:3.6f}'.format(
                epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader), val_acc/len(val_set), val_loss/len(val_loader)
            ))

            # if the model improves, save a checkpoint at this epoch
            if val_acc > best_acc:
                best_acc = val_acc
                torch.save(model.state_dict(), model_path)
                print('saving model with acc {:.3f}'.format(best_acc/len(val_set)))
    else:
        print('[{:03d}/{:03d}] Train Acc: {:3.6f} Loss: {:3.6f}'.format(
            epoch + 1, num_epoch, train_acc/len(train_set), train_loss/len(train_loader)
        ))

# if not validating, save the last epoch
if len(val_set) == 0:
    torch.save(model.state_dict(), model_path)
    print('saving model at last epoch')
# Out:
# [001/250] Train Acc: 0.385302 Loss: 3.774057
# [002/250] Train Acc: 0.522625 Loss: 3.091101
# [003/250] Train Acc: 0.567984 Loss: 2.827559
# [004/250] Train Acc: 0.595037 Loss: 2.627228
# [005/250] Train Acc: 0.613059 Loss: 2.458342
# [006/250] Train Acc: 0.627666 Loss: 2.311500
# [007/250] Train Acc: 0.638813 Loss: 2.185113
# [008/250] Train Acc: 0.647801 Loss: 2.076537
# [009/250] Train Acc: 0.655257 Loss: 1.988262
# [010/250] Train Acc: 0.661449 Loss: 1.912144
# [011/250] Train Acc: 0.666893 Loss: 1.849963
# [012/250] Train Acc: 0.671618 Loss: 1.797631
# [013/250] Train Acc: 0.675911 Loss: 1.755273
# [014/250] Train Acc: 0.679741 Loss: 1.715894
# [015/250] Train Acc: 0.682837 Loss: 1.685744
# [016/250] Train Acc: 0.686518 Loss: 1.657172
# [017/250] Train Acc: 0.689672 Loss: 1.632060
# [018/250] Train Acc: 0.692683 Loss: 1.610316
# [019/250] Train Acc: 0.694857 Loss: 1.592502
# [020/250] Train Acc: 0.697940 Loss: 1.573131
# [021/250] Train Acc: 0.700326 Loss: 1.557883
# [022/250] Train Acc: 0.702642 Loss: 1.544698
# [023/250] Train Acc: 0.705238 Loss: 1.530524
# [024/250] Train Acc: 0.706875 Loss: 1.518757
# [025/250] Train Acc: 0.709209 Loss: 1.508332
# [026/250] Train Acc: 0.711509 Loss: 1.497191
# [027/250] Train Acc: 0.713228 Loss: 1.488711
# [028/250] Train Acc: 0.715472 Loss: 1.479411
# [029/250] Train Acc: 0.716978 Loss: 1.473101
# [030/250] Train Acc: 0.719992 Loss: 1.463182
# [031/250] Train Acc: 0.721071 Loss: 1.457241
# [032/250] Train Acc: 0.722805 Loss: 1.451629
# [033/250] Train Acc: 0.724921 Loss: 1.444583
# [034/250] Train Acc: 0.725551 Loss: 1.440272
# [035/250] Train Acc: 0.727987 Loss: 1.432841
# [036/250] Train Acc: 0.728785 Loss: 1.429368
# [037/250] Train Acc: 0.730153 Loss: 1.424228
# [038/250] Train Acc: 0.731611 Loss: 1.420595
# [039/250] Train Acc: 0.733164 Loss: 1.415395
# [040/250] Train Acc: 0.734471 Loss: 1.411236
# [041/250] Train Acc: 0.735684 Loss: 1.406822
# [042/250] Train Acc: 0.736546 Loss: 1.404213
# [043/250] Train Acc: 0.736998 Loss: 1.402230
# [044/250] Train Acc: 0.739350 Loss: 1.397082
# [045/250] Train Acc: 0.740291 Loss: 1.393682
# [046/250] Train Acc: 0.741393 Loss: 1.390778
# [047/250] Train Acc: 0.741967 Loss: 1.388192
# [048/250] Train Acc: 0.742799 Loss: 1.385930
# [049/250] Train Acc: 0.743720 Loss: 1.383207
# [050/250] Train Acc: 0.744930 Loss: 1.380301
# [051/250] Train Acc: 0.745710 Loss: 1.377797
# [052/250] Train Acc: 0.745824 Loss: 1.377128
# [053/250] Train Acc: 0.746966 Loss: 1.373224
# [054/250] Train Acc: 0.747622 Loss: 1.371531
# [055/250] Train Acc: 0.748416 Loss: 1.368980
# [056/250] Train Acc: 0.750265 Loss: 1.365813
# [057/250] Train Acc: 0.750012 Loss: 1.364203
# [058/250] Train Acc: 0.750856 Loss: 1.363728
# [059/250] Train Acc: 0.751358 Loss: 1.360773
# [060/250] Train Acc: 0.751884 Loss: 1.360078
# [061/250] Train Acc: 0.752331 Loss: 1.357941
# [062/250] Train Acc: 0.753238 Loss: 1.356179
# [063/250] Train Acc: 0.753250 Loss: 1.355234
# [064/250] Train Acc: 0.754621 Loss: 1.352818
# [065/250] Train Acc: 0.755115 Loss: 1.350773
# [066/250] Train Acc: 0.755560 Loss: 1.349388
# [067/250] Train Acc: 0.755627 Loss: 1.348845
# [068/250] Train Acc: 0.756343 Loss: 1.347083
# [069/250] Train Acc: 0.756791 Loss: 1.345549
# [070/250] Train Acc: 0.758315 Loss: 1.342873
# [071/250] Train Acc: 0.757768 Loss: 1.343685
# [072/250] Train Acc: 0.759172 Loss: 1.340563
# [073/250] Train Acc: 0.759090 Loss: 1.339925
# [074/250] Train Acc: 0.759160 Loss: 1.338376
# [075/250] Train Acc: 0.759657 Loss: 1.337780
# [076/250] Train Acc: 0.760428 Loss: 1.336658
# [077/250] Train Acc: 0.761237 Loss: 1.335767
# [078/250] Train Acc: 0.760664 Loss: 1.335336
# [079/250] Train Acc: 0.761404 Loss: 1.333756
# [080/250] Train Acc: 0.761810 Loss: 1.331640
# [081/250] Train Acc: 0.762971 Loss: 1.328833
# [082/250] Train Acc: 0.762890 Loss: 1.329752
# [083/250] Train Acc: 0.763835 Loss: 1.328341
# [084/250] Train Acc: 0.763833 Loss: 1.328796
# [085/250] Train Acc: 0.763949 Loss: 1.326113
# [086/250] Train Acc: 0.764338 Loss: 1.325194
# [087/250] Train Acc: 0.764685 Loss: 1.323673
# [088/250] Train Acc: 0.764945 Loss: 1.323013
# [089/250] Train Acc: 0.765767 Loss: 1.322067
# [090/250] Train Acc: 0.765966 Loss: 1.321701
# [091/250] Train Acc: 0.766247 Loss: 1.320543
# [092/250] Train Acc: 0.765726 Loss: 1.320943
# [093/250] Train Acc: 0.767083 Loss: 1.318427
# [094/250] Train Acc: 0.766915 Loss: 1.317018
# [095/250] Train Acc: 0.767543 Loss: 1.316200
# [096/250] Train Acc: 0.767660 Loss: 1.316794
# [097/250] Train Acc: 0.766904 Loss: 1.317275
# [098/250] Train Acc: 0.768502 Loss: 1.313459
# [099/250] Train Acc: 0.768431 Loss: 1.313023
# [100/250] Train Acc: 0.768488 Loss: 1.313056
# [101/250] Train Acc: 0.769162 Loss: 1.312800
# [102/250] Train Acc: 0.769202 Loss: 1.311511
# [103/250] Train Acc: 0.769781 Loss: 1.311222
# [104/250] Train Acc: 0.770161 Loss: 1.309120
# [105/250] Train Acc: 0.770246 Loss: 1.310202
# [106/250] Train Acc: 0.770420 Loss: 1.308657
# [107/250] Train Acc: 0.770834 Loss: 1.308614
# [108/250] Train Acc: 0.771363 Loss: 1.307182
# [109/250] Train Acc: 0.771291 Loss: 1.306901
# [110/250] Train Acc: 0.771621 Loss: 1.304704
# [111/250] Train Acc: 0.771072 Loss: 1.305242
# [112/250] Train Acc: 0.772205 Loss: 1.303169
# [113/250] Train Acc: 0.772424 Loss: 1.303885
# [114/250] Train Acc: 0.772924 Loss: 1.301173
# [115/250] Train Acc: 0.772999 Loss: 1.301579
# [116/250] Train Acc: 0.772745 Loss: 1.301287
# [117/250] Train Acc: 0.772831 Loss: 1.300325
# [118/250] Train Acc: 0.773650 Loss: 1.298720
# [119/250] Train Acc: 0.772902 Loss: 1.300754
# [120/250] Train Acc: 0.774206 Loss: 1.297445
# [121/250] Train Acc: 0.773819 Loss: 1.300408
# [122/250] Train Acc: 0.774662 Loss: 1.296394
# [123/250] Train Acc: 0.774816 Loss: 1.296467
# [124/250] Train Acc: 0.774404 Loss: 1.297435
# [125/250] Train Acc: 0.774729 Loss: 1.296506
# [126/250] Train Acc: 0.774870 Loss: 1.296437
# [127/250] Train Acc: 0.775735 Loss: 1.294035
# [128/250] Train Acc: 0.775237 Loss: 1.295104
# [129/250] Train Acc: 0.775764 Loss: 1.293877
# [130/250] Train Acc: 0.775643 Loss: 1.293012
# [131/250] Train Acc: 0.775902 Loss: 1.292178
# [132/250] Train Acc: 0.775954 Loss: 1.292222
# [133/250] Train Acc: 0.775540 Loss: 1.293351
# [134/250] Train Acc: 0.776453 Loss: 1.292031
# [135/250] Train Acc: 0.776304 Loss: 1.291713
# [136/250] Train Acc: 0.776703 Loss: 1.291444
# [137/250] Train Acc: 0.776933 Loss: 1.290733
# [138/250] Train Acc: 0.777640 Loss: 1.288849
# [139/250] Train Acc: 0.777523 Loss: 1.288525
# [140/250] Train Acc: 0.776855 Loss: 1.289778
# [141/250] Train Acc: 0.777831 Loss: 1.287564
# [142/250] Train Acc: 0.778055 Loss: 1.287462
# [143/250] Train Acc: 0.777892 Loss: 1.287312
# [144/250] Train Acc: 0.778214 Loss: 1.285356
# [145/250] Train Acc: 0.778644 Loss: 1.286073
# [146/250] Train Acc: 0.778193 Loss: 1.285410
# [147/250] Train Acc: 0.779181 Loss: 1.284428
# [148/250] Train Acc: 0.778779 Loss: 1.284584
# [149/250] Train Acc: 0.778898 Loss: 1.284679
# [150/250] Train Acc: 0.779038 Loss: 1.283726
# [151/250] Train Acc: 0.779322 Loss: 1.282151
# [152/250] Train Acc: 0.779814 Loss: 1.281954
# [153/250] Train Acc: 0.779773 Loss: 1.280629
# [154/250] Train Acc: 0.779822 Loss: 1.281229
# [155/250] Train Acc: 0.779332 Loss: 1.281848
# [156/250] Train Acc: 0.780478 Loss: 1.279272
# [157/250] Train Acc: 0.780250 Loss: 1.279425
# [158/250] Train Acc: 0.780563 Loss: 1.278925
# [159/250] Train Acc: 0.780806 Loss: 1.279106
# [160/250] Train Acc: 0.780347 Loss: 1.278662
# [161/250] Train Acc: 0.780489 Loss: 1.278348
# [162/250] Train Acc: 0.780898 Loss: 1.278459
# [163/250] Train Acc: 0.780652 Loss: 1.277529
# [164/250] Train Acc: 0.780734 Loss: 1.277271
# [165/250] Train Acc: 0.781014 Loss: 1.277089
# [166/250] Train Acc: 0.781020 Loss: 1.276380
# [167/250] Train Acc: 0.781377 Loss: 1.275179
# [168/250] Train Acc: 0.781973 Loss: 1.275152
# [169/250] Train Acc: 0.782229 Loss: 1.274376
# [170/250] Train Acc: 0.781808 Loss: 1.274756
# [171/250] Train Acc: 0.782620 Loss: 1.272672
# [172/250] Train Acc: 0.781494 Loss: 1.275138
# [173/250] Train Acc: 0.782349 Loss: 1.272157
# [174/250] Train Acc: 0.782741 Loss: 1.271948
# [175/250] Train Acc: 0.783287 Loss: 1.272384
# [176/250] Train Acc: 0.782793 Loss: 1.272453
# [177/250] Train Acc: 0.782165 Loss: 1.273016
# [178/250] Train Acc: 0.782909 Loss: 1.271338
# [179/250] Train Acc: 0.783280 Loss: 1.270926
# [180/250] Train Acc: 0.782928 Loss: 1.270656
# [181/250] Train Acc: 0.783618 Loss: 1.268387
# [182/250] Train Acc: 0.783224 Loss: 1.269178
# [183/250] Train Acc: 0.784028 Loss: 1.270025
# [184/250] Train Acc: 0.783613 Loss: 1.269218
# [185/250] Train Acc: 0.783821 Loss: 1.267885
# [186/250] Train Acc: 0.783802 Loss: 1.269327
# [187/250] Train Acc: 0.783367 Loss: 1.269134
# [188/250] Train Acc: 0.784446 Loss: 1.267197
# [189/250] Train Acc: 0.784562 Loss: 1.266794
# [190/250] Train Acc: 0.784472 Loss: 1.267640
# [191/250] Train Acc: 0.784645 Loss: 1.266608
# [192/250] Train Acc: 0.784706 Loss: 1.265670
# [193/250] Train Acc: 0.784924 Loss: 1.265565
# [194/250] Train Acc: 0.784905 Loss: 1.265677
# [195/250] Train Acc: 0.784623 Loss: 1.265809
# [196/250] Train Acc: 0.785182 Loss: 1.265501
# [197/250] Train Acc: 0.785837 Loss: 1.263679
# [198/250] Train Acc: 0.784933 Loss: 1.264036
# [199/250] Train Acc: 0.785368 Loss: 1.263923
# [200/250] Train Acc: 0.785392 Loss: 1.264479
# [201/250] Train Acc: 0.785517 Loss: 1.262372
# [202/250] Train Acc: 0.786196 Loss: 1.262083
# [203/250] Train Acc: 0.785366 Loss: 1.263079
# [204/250] Train Acc: 0.785689 Loss: 1.261957
# [205/250] Train Acc: 0.786539 Loss: 1.261240
# [206/250] Train Acc: 0.785881 Loss: 1.261155
# [207/250] Train Acc: 0.785829 Loss: 1.261929
# [208/250] Train Acc: 0.785530 Loss: 1.262333
# [209/250] Train Acc: 0.785899 Loss: 1.260885
# [210/250] Train Acc: 0.786138 Loss: 1.260463
# [211/250] Train Acc: 0.786695 Loss: 1.258912
# [212/250] Train Acc: 0.786004 Loss: 1.260133
# [213/250] Train Acc: 0.786253 Loss: 1.259450
# [214/250] Train Acc: 0.786771 Loss: 1.260071
# [215/250] Train Acc: 0.786460 Loss: 1.260248
# [216/250] Train Acc: 0.787008 Loss: 1.258092
# [217/250] Train Acc: 0.787325 Loss: 1.258870
# [218/250] Train Acc: 0.787383 Loss: 1.257261
# [219/250] Train Acc: 0.787873 Loss: 1.256841
# [220/250] Train Acc: 0.787405 Loss: 1.257104
# [221/250] Train Acc: 0.786768 Loss: 1.258916
# [222/250] Train Acc: 0.787157 Loss: 1.257217
# [223/250] Train Acc: 0.787453 Loss: 1.256953
# [224/250] Train Acc: 0.788173 Loss: 1.254495
# [225/250] Train Acc: 0.786990 Loss: 1.255776
# [226/250] Train Acc: 0.787380 Loss: 1.255854
# [227/250] Train Acc: 0.787858 Loss: 1.255116
# [228/250] Train Acc: 0.788150 Loss: 1.254990
# [229/250] Train Acc: 0.787734 Loss: 1.254888
# [230/250] Train Acc: 0.787709 Loss: 1.255305
# [231/250] Train Acc: 0.787868 Loss: 1.254318
# [232/250] Train Acc: 0.788009 Loss: 1.253911
# [233/250] Train Acc: 0.788482 Loss: 1.253863
# [234/250] Train Acc: 0.787640 Loss: 1.253693
# [235/250] Train Acc: 0.788493 Loss: 1.252575
# [236/250] Train Acc: 0.788927 Loss: 1.252069
# [237/250] Train Acc: 0.788496 Loss: 1.253051
# [238/250] Train Acc: 0.789065 Loss: 1.251910
# [239/250] Train Acc: 0.788982 Loss: 1.252126
# [240/250] Train Acc: 0.788761 Loss: 1.252240
# [241/250] Train Acc: 0.788896 Loss: 1.251775
# [242/250] Train Acc: 0.789318 Loss: 1.250485
# [243/250] Train Acc: 0.789059 Loss: 1.250954
# [244/250] Train Acc: 0.789398 Loss: 1.250436
# [245/250] Train Acc: 0.789213 Loss: 1.250292
# [246/250] Train Acc: 0.789179 Loss: 1.249586
# [247/250] Train Acc: 0.788806 Loss: 1.250312
# [248/250] Train Acc: 0.789776 Loss: 1.249168
# [249/250] Train Acc: 0.789124 Loss: 1.249393
# [250/250] Train Acc: 0.790370 Loss: 1.248349
# saving model at last epoch

# %% [markdown]
# ## Testing

# %% [markdown]
# Create a testing dataset, and load model from the saved checkpoint.

# %%
# create testing dataset
test_set = TIMITDataset(test, None)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE, shuffle=False)

# create model and load weights from checkpoint
model = Classifier().to(device)
model.load_state_dict(torch.load(model_path))
# Out:
# <All keys matched successfully>

# %% [markdown]
# Make prediction.

# %%
predict = []
model.eval() # set the model to evaluation mode
with torch.no_grad():
    for i, data in enumerate(test_loader):
        inputs = data
        inputs = inputs.to(device)
        outputs = model(inputs)
        _, test_pred = torch.max(outputs, 1) # get the index of the class with the highest probability

        for y in test_pred.cpu().numpy():
            predict.append(y)

# %% [markdown]
# Post-Process

# %%
def post_process():
  count = 0
  for index in range(1, len(predict)-1):
    pre = predict[index-1]
    cur = predict[index]
    nex = predict[index+1]
    if pre == nex and pre != cur:
      print('index', index, 'correct', cur, 'to', pre)
      predict[index] = pre
      count += 1
  print('correction: %d, precentage: %.3f'%(count, count/len(predict)))
post_process()
# Out:
# index 163 correct 2 to 4
# index 249 correct 21 to 35
# index 403 correct 20 to 19
# index 551 correct 11 to 7
# index 601 correct 4 to 12
# index 800 correct 4 to 10
# index 807 correct 23 to 13
# index 932 correct 30 to 27
# index 953 correct 4 to 7
# index 1018 correct 18 to 19
# index 1111 correct 29 to 25
# index 1156 correct 16 to 13
# index 1193 correct 13 to 5
# index 1281 correct 35 to 31
# index 1394 correct 12 to 5
# index 1413 correct 5 to 38
# index 1425 correct 31 to 35
# index 1525 correct 33 to 38
# index 1538 correct 1 to 2
# index 1601 correct 12 to 2
# index 1603 correct 12 to 2
# index 1713 correct 38 to 33
# index 1775 correct 21 to 29
# index 1876 correct 27 to 38
# index 1895 correct 7 to 9
# index 1925 correct 4 to 12
# index 2115 correct 33 to 38
# index 2143 correct 9 to 3
# index 2211 correct 35 to 31
# index 2316 correct 14 to 17
# index 2336 correct 31 to 35
# index 2349 correct 31 to 35
# index 2578 correct 24 to 14
# index 2621 correct 31 to 35
# index 2623 correct 31 to 35
# index 2663 correct 4 to 7
# index 2669 correct 9 to 7
# index 2842 correct 4 to 1
# index 2867 correct 7 to 4
# index 2885 correct 14 to 17
# index 3024 correct 13 to 12
# index 3053 correct 8 to 3
# index 3149 correct 14 to 9
# index 3160 correct 31 to 35
# index 3393 correct 0 to 5
# index 3453 correct 35 to 31
# index 3505 correct 1 to 19
# index 3607 correct 38 to 35
# index 3649 correct 3 to 2
# index 3654 correct 3 to 2
# index 3656 correct 3 to 2
# index 3762 correct 14 to 7
# index 3783 correct 1 to 38
# index 3802 correct 29 to 38
# index 4577 correct 2 to 3
# index 4604 correct 17 to 1
# index 4731 correct 1 to 15
# index 4798 correct 1 to 9
# index 5211 correct 18 to 19
# index 5291 correct 13 to 19
# index 5580 correct 3 to 2
# index 5705 correct 3 to 1
# index 6103 correct 29 to 30
# index 6285 correct 1 to 10
# index 6588 correct 7 to 17
# index 6650 correct 38 to 19
# index 6677 correct 11 to 13
# index 6753 correct 28 to 30
# index 6890 correct 1 to 0
# index 7251 correct 2 to 3
# index 7300 correct 1 to 0
# index 7413 correct 2 to 3
# index 7789 correct 38 to 18
# index 7858 correct 33 to 34
# index 7974 correct 8 to 1
# index 8009 correct 5 to 1
# index 8024 correct 4 to 2
# index 8104 correct 35 to 36
# index 8125 correct 38 to 1
# index 8297 correct 12 to 4
# index 8315 correct 12 to 7
# index 8323 correct 18 to 14
# index 8709 correct 2 to 1
# index 8711 correct 2 to 1
# index 8918 correct 14 to 7
# index 9200 correct 16 to 14
# index 9520 correct 20 to 19
# index 9551 correct 19 to 18
# index 9574 correct 29 to 35
# index 9736 correct 4 to 2
# index 10070 correct 31 to 35
# index 10098 correct 1 to 12
# index 10379 correct 14 to 17
# index 10516 correct 4 to 17
# index 10531 correct 9 to 7
# index 10604 correct 32 to 38
# index 11088 correct 3 to 4
# index 11841 correct 1 to 2
# index 11912 correct 34 to 23
# index 11914 correct 34 to 23
# index 12147 correct 12 to 13
# index 12320 correct 1 to 0
# index 12635 correct 30 to 37
# index 12672 correct 2 to 3
# index 12684 correct 27 to 30
# index 12736 correct 13 to 7
# index 12748 correct 29 to 35
# index 12995 correct 12 to 13
# index 13234 correct 2 to 11
# index 13241 correct 2 to 4
# index 13476 correct 1 to 8
# index 13740 correct 36 to 35
# index 14272 correct 35 to 36
# index 14274 correct 35 to 36
# index 14518 correct 38 to 13
# index 14984 correct 0 to 1
# index 15099 correct 28 to 38
# index 15199 correct 19 to 1
# index 15222 correct 35 to 36
# index 15225 correct 35 to 36
# index 15297 correct 3 to 11
# index 15346 correct 13 to 12
# index 15391 correct 19 to 18
# index 15427 correct 7 to 4
# index 15707 correct 2 to 3
# index 15866 correct 2 to 1
# index 16177 correct 3 to 7
# index 16515 correct 2 to 3
# index 17092 correct 19 to 1
# index 17223 correct 4 to 2
# index 17456 correct 12 to 2
# index 17465 correct 3 to 2
# index 17693 correct 4 to 1
# index 18317 correct 20 to 1
# index 18576 correct 6 to 1
# index 18793 correct 14 to 17
# index 18824 correct 5 to 0
# index 18856 correct 31 to 35
# index 19360 correct 10 to 7
# index 19591 correct 5 to 0
# index 19653 correct 2 to 3
# index 19666 correct 23 to 29
# index 19721 correct 19 to 38
# index 19777 correct 19 to 38
# index 19790 correct 35 to 31
# index 19836 correct 38 to 35
# index 19856 correct 16 to 13
# index 19970 correct 17 to 14
# index 20025 correct 38 to 16
# index 20457 correct 7 to 4
# index 20867 correct 7 to 9
# index 21278 correct 2 to 3
# index 21407 correct 30 to 35
# index 21432 correct 2 to 3
# index 21651 correct 0 to 5
# index 21855 correct 1 to 19
# index 22292 correct 18 to 19
# index 22474 correct 38 to 35
# index 22547 correct 33 to 38
# index 22713 correct 19 to 20
# index 22745 correct 30 to 38
# index 22939 correct 8 to 1
# index 23214 correct 7 to 3
# index 23465 correct 38 to 21
# index 23467 correct 36 to 21
# index 23778 correct 13 to 12
# index 24005 correct 3 to 38
# index 24216 correct 4 to 7
# index 24518 correct 0 to 1
# index 24578 correct 31 to 35
# index 24625 correct 19 to 26
# index 24641 correct 2 to 1
# index 24726 correct 10 to 13
# index 24879 correct 2 to 3
# index 25032 correct 18 to 19
# index 25138 correct 22 to 21
# index 25226 correct 34 to 35
# index 25242 correct 37 to 38
# index 25583 correct 9 to 7
# index 26058 correct 23 to 32
# index 26211 correct 4 to 13
# index 26589 correct 12 to 7
# index 27271 correct 16 to 5
# index 27358 correct 12 to 4
# index 27489 correct 2 to 3
# index 27732 correct 7 to 19
# index 27744 correct 4 to 7
# index 27932 correct 0 to 5
# index 27955 correct 14 to 17
# index 28114 correct 9 to 3
# index 28283 correct 12 to 7
# index 28421 correct 7 to 4
# index 28538 correct 26 to 8
# index 28620 correct 7 to 9
# index 28654 correct 4 to 7
# index 29841 correct 4 to 2
# index 29843 correct 4 to 2
# index 30075 correct 4 to 2
# index 30284 correct 1 to 0
# index 30506 correct 0 to 5
# index 30642 correct 25 to 38
# index 30889 correct 16 to 5
# index 31023 correct 9 to 8
# index 31188 correct 1 to 0
# index 31331 correct 8 to 9
# index 31391 correct 4 to 9
# index 31654 correct 12 to 4
# index 32340 correct 3 to 11
# index 32469 correct 38 to 23
# index 32487 correct 4 to 3
# index 32615 correct 12 to 7
# index 32722 correct 19 to 20
# index 32801 correct 7 to 5
# index 32902 correct 38 to 23
# index 33048 correct 33 to 28
# index 33181 correct 12 to 5
# index 33221 correct 35 to 31
# index 33223 correct 35 to 31
# index 33286 correct 9 to 7
# index 33612 correct 8 to 10
# index 33614 correct 9 to 10
# index 33866 correct 10 to 7
# index 33901 correct 9 to 10
# index 34005 correct 2 to 1
# index 34023 correct 36 to 22
# index 34046 correct 4 to 12
# index 34304 correct 31 to 35
# index 34423 correct 10 to 13
# index 34877 correct 26 to 19
# index 35136 correct 1 to 0
# index 35212 correct 28 to 29
# index 35289 correct 9 to 3
# index 35330 correct 21 to 35
# index 35413 correct 3 to 11
# index 35435 correct 18 to 19
# index 35485 correct 38 to 32
# index 35567 correct 38 to 30
# index 35658 correct 0 to 1
# index 35759 correct 35 to 31
# index 35797 correct 35 to 31
# index 35859 correct 7 to 13
# index 35891 correct 4 to 1
# index 35969 correct 1 to 2
# index 36020 correct 1 to 2
# index 36112 correct 11 to 7
# index 36225 correct 4 to 12
# index 36579 correct 1 to 2
# index 36597 correct 33 to 34
# index 36618 correct 12 to 13
# index 36836 correct 11 to 9
# index 36984 correct 29 to 22
# index 37003 correct 11 to 13
# index 37028 correct 38 to 35
# index 37158 correct 34 to 33
# index 37754 correct 20 to 19
# index 37819 correct 38 to 7
# index 37880 correct 30 to 38
# index 38098 correct 1 to 3
# index 38159 correct 33 to 28
# index 38231 correct 15 to 1
# index 38234 correct 12 to 1
# index 38599 correct 29 to 23
# index 38748 correct 19 to 18
# index 38794 correct 0 to 8
# index 39054 correct 35 to 21
# index 39102 correct 1 to 2
# index 39204 correct 7 to 4
# index 39265 correct 7 to 4
# index 39553 correct 19 to 26
# index 39654 correct 1 to 2
# index 39752 correct 14 to 17
# index 39807 correct 38 to 3
# index 39809 correct 2 to 3
# index 40049 correct 2 to 3
# index 40122 correct 11 to 3
# index 40181 correct 9 to 7
# index 40226 correct 30 to 27
# index 40320 correct 21 to 36
# index 40484 correct 18 to 19
# index 40598 correct 29 to 38
# index 40614 correct 20 to 19
# index 41171 correct 21 to 36
# index 41761 correct 28 to 29
# index 41881 correct 14 to 17
# index 42246 correct 1 to 0
# index 42269 correct 12 to 13
# index 42392 correct 2 to 3
# index 42492 correct 17 to 1
# index 42497 correct 35 to 36
# index 42499 correct 35 to 36
# index 42603 correct 13 to 16
# index 42605 correct 13 to 16
# index 42786 correct 28 to 29
# index 43021 correct 19 to 38
# index 43287 correct 31 to 35
# index 43634 correct 9 to 3
# index 44111 correct 3 to 8
# index 44295 correct 17 to 14
# index 44321 correct 1 to 5
# index 44380 correct 13 to 12
# index 44507 correct 14 to 17
# index 44642 correct 33 to 32
# index 44646 correct 33 to 32
# index 44775 correct 1 to 17
# index 44853 correct 38 to 37
# index 45138 correct 0 to 38
# index 45310 correct 1 to 5
# index 45315 correct 17 to 1
# index 45459 correct 7 to 9
# index 45502 correct 19 to 26
# index 45786 correct 34 to 38
# index 46015 correct 31 to 35
# index 46386 correct 36 to 35
# index 46632 correct 33 to 38
# index 46725 correct 1 to 0
# index 46951 correct 35 to 36
# index 47021 correct 13 to 16
# index 47354 correct 22 to 31
# index 47382 correct 8 to 1
# index 47451 correct 34 to 38
# index 47569 correct 24 to 28
# index 47636 correct 35 to 22
# index 47641 correct 21 to 22
# index 47794 correct 21 to 35
# index 47823 correct 14 to 17
# index 47829 correct 2 to 17
# index 47896 correct 4 to 12
# index 48020 correct 21 to 35
# index 48112 correct 7 to 9
# index 48145 correct 30 to 38
# index 48194 correct 8 to 0
# index 48230 correct 12 to 4
# index 48329 correct 35 to 36
# index 48390 correct 38 to 37
# index 48401 correct 9 to 7
# index 48414 correct 35 to 21
# index 48472 correct 12 to 1
# index 48532 correct 7 to 4
# index 48562 correct 35 to 22
# index 48612 correct 1 to 0
# index 48624 correct 38 to 19
# index 48720 correct 25 to 29
# index 48768 correct 36 to 31
# index 48799 correct 22 to 31
# index 48810 correct 37 to 38
# index 48852 correct 31 to 35
# index 48946 correct 21 to 35
# index 49151 correct 1 to 5
# index 49221 correct 7 to 4
# index 49756 correct 13 to 4
# index 49885 correct 13 to 12
# index 49953 correct 18 to 19
# index 50014 correct 4 to 17
# index 50100 correct 17 to 14
# index 50198 correct 0 to 1
# index 50240 correct 15 to 37
# index 50361 correct 14 to 17
# index 50484 correct 4 to 1
# index 50562 correct 38 to 30
# index 50667 correct 17 to 1
# index 50776 correct 30 to 38
# index 50784 correct 30 to 29
# index 50832 correct 15 to 0
# index 50953 correct 1 to 19
# index 51023 correct 12 to 7
# index 51090 correct 17 to 2
# index 51309 correct 32 to 38
# index 51490 correct 4 to 7
# index 51606 correct 14 to 17
# index 51667 correct 12 to 13
# index 51715 correct 1 to 8
# index 51768 correct 1 to 5
# index 51771 correct 1 to 5
# index 51773 correct 1 to 5
# index 51789 correct 0 to 1
# index 51843 correct 15 to 0
# index 51984 correct 29 to 38
# index 52278 correct 8 to 1
# index 52486 correct 35 to 31
# index 52585 correct 31 to 35
# index 52812 correct 0 to 37
# index 52872 correct 27 to 30
# index 52913 correct 4 to 1
# index 52988 correct 29 to 38
# index 53191 correct 1 to 8
# index 53214 correct 1 to 12
# index 53252 correct 0 to 15
# index 53338 correct 7 to 12
# index 53892 correct 1 to 4
# index 54014 correct 5 to 1
# index 54189 correct 31 to 35
# index 54192 correct 31 to 35
# index 54246 correct 21 to 22
# index 54428 correct 28 to 38
# index 54431 correct 32 to 23
# index 54865 correct 20 to 19
# index 55174 correct 10 to 7
# index 55357 correct 11 to 7
# index 55476 correct 7 to 12
# index 55539 correct 8 to 3
# index 55712 correct 3 to 2
# index 55727 correct 28 to 33
# index 55742 correct 5 to 7
# index 55837 correct 2 to 1
# index 55845 correct 18 to 38
# index 56071 correct 26 to 19
# index 56262 correct 14 to 17
# index 56287 correct 19 to 38
# index 56545 correct 14 to 17
# index 56929 correct 3 to 9
# index 57293 correct 31 to 35
# index 57333 correct 21 to 35
# index 57387 correct 22 to 25
# index 57733 correct 4 to 13
# index 57997 correct 1 to 0
# index 58335 correct 1 to 8
# index 58407 correct 1 to 0
# index 58410 correct 19 to 0
# index 58443 correct 34 to 38
# index 58713 correct 28 to 33
# index 58740 correct 38 to 33
# index 58778 correct 21 to 35
# index 59003 correct 2 to 1
# index 59067 correct 28 to 33
# index 59089 correct 20 to 19
# index 59116 correct 3 to 2
# index 59161 correct 1 to 2
# index 59272 correct 8 to 1
# index 59321 correct 1 to 0
# index 59343 correct 38 to 32
# index 59484 correct 14 to 10
# index 59570 correct 22 to 35
# index 59585 correct 8 to 0
# index 59611 correct 1 to 8
# index 59741 correct 9 to 8
# index 60330 correct 30 to 38
# index 60690 correct 33 to 38
# index 60702 correct 38 to 34
# index 60913 correct 11 to 12
# index 60962 correct 31 to 35
# index 61015 correct 38 to 33
# index 61286 correct 4 to 13
# index 61367 correct 9 to 7
# index 61631 correct 19 to 1
# index 61657 correct 19 to 1
# index 61664 correct 35 to 31
# index 61910 correct 38 to 33
# index 61926 correct 11 to 13
# index 62720 correct 3 to 11
# index 63533 correct 9 to 3
# index 63687 correct 4 to 12
# index 63737 correct 10 to 12
# index 63908 correct 4 to 7
# index 63961 correct 11 to 7
# index 64416 correct 31 to 35
# index 64725 correct 9 to 8
# index 64736 correct 15 to 1
# index 64997 correct 31 to 35
# index 65133 correct 4 to 1
# index 65454 correct 8 to 9
# index 65548 correct 17 to 1
# index 65588 correct 23 to 35
# index 65632 correct 1 to 4
# index 65678 correct 2 to 1
# index 65692 correct 5 to 17
# index 66420 correct 3 to 2
# index 66638 correct 30 to 29
# index 66945 correct 36 to 35
# index 66991 correct 8 to 2
# index 67064 correct 11 to 4
# index 67466 correct 8 to 0
# index 67520 correct 28 to 34
# index 67528 correct 34 to 33
# index 67540 correct 9 to 12
# index 67748 correct 7 to 9
# index 68336 correct 31 to 35
# index 68416 correct 22 to 38
# index 68776 correct 31 to 35
# index 69216 correct 38 to 10
# index 69359 correct 12 to 4
# index 69432 correct 2 to 3
# index 69485 correct 17 to 4
# index 69551 correct 31 to 35
# index 69710 correct 30 to 38
# index 69925 correct 19 to 18
# index 69974 correct 0 to 8
# index 70440 correct 31 to 35
# index 70453 correct 8 to 0
# index 70822 correct 8 to 9
# index 71111 correct 38 to 34
# index 71368 correct 29 to 30
# index 71505 correct 8 to 13
# index 72199 correct 12 to 4
# index 72214 correct 2 to 17
# index 72433 correct 1 to 2
# index 72606 correct 34 to 19
# index 72665 correct 35 to 31
# index 72931 correct 23 to 38
# index 72987 correct 30 to 3
# index 73003 correct 7 to 11
# index 73176 correct 2 to 1
# index 73375 correct 1 to 0
# index 73716 correct 4 to 7
# index 73814 correct 11 to 7
# index 74138 correct 5 to 1
# index 74208 correct 35 to 31
# index 74212 correct 31 to 35
# index 74231 correct 4 to 2
# index 74256 correct 38 to 33
# index 74295 correct 31 to 35
# index 74309 correct 32 to 38
# index 74557 correct 29 to 38
# index 74815 correct 26 to 38
# index 74926 correct 3 to 8
# index 75010 correct 32 to 38
# index 75091 correct 9 to 7
# index 75095 correct 3 to 7
# index 75208 correct 38 to 35
# index 75442 correct 7 to 11
# index 75553 correct 32 to 38
# index 75828 correct 7 to 9
# index 75857 correct 2 to 1
# index 75879 correct 7 to 11
# index 75886 correct 13 to 38
# index 75935 correct 7 to 9
# index 75937 correct 7 to 9
# index 75968 correct 3 to 2
# index 76171 correct 2 to 1
# index 76208 correct 23 to 38
# index 76279 correct 31 to 35
# index 76281 correct 31 to 35
# index 76525 correct 0 to 1
# index 76681 correct 34 to 38
# index 76756 correct 38 to 19
# index 76884 correct 35 to 31
# index 76897 correct 1 to 2
# index 77121 correct 8 to 0
# index 77711 correct 17 to 1
# index 78194 correct 1 to 2
# index 78272 correct 7 to 3
# index 78452 correct 0 to 1
# index 78555 correct 1 to 0
# index 78641 correct 2 to 3
# index 78720 correct 17 to 1
# index 78913 correct 5 to 14
# index 78935 correct 37 to 33
# index 78966 correct 22 to 21
# index 79084 correct 4 to 7
# index 79139 correct 29 to 21
# index 79317 correct 5 to 1
# index 79340 correct 1 to 0
# index 79356 correct 33 to 38
# index 79396 correct 5 to 0
# index 79464 correct 1 to 4
# index 79537 correct 5 to 0
# index 79546 correct 0 to 1
# index 79566 correct 9 to 7
# index 79584 correct 34 to 30
# index 79597 correct 5 to 1
# index 79709 correct 3 to 8
# index 79752 correct 17 to 14
# index 80366 correct 0 to 8
# index 80379 correct 18 to 19
# index 80469 correct 4 to 2
# index 80493 correct 4 to 1
# index 80565 correct 25 to 38
# index 80577 correct 37 to 30
# index 80590 correct 13 to 12
# index 80727 correct 22 to 21
# index 80773 correct 2 to 9
# index 80830 correct 31 to 35
# index 81223 correct 1 to 2
# index 81514 correct 35 to 31
# index 81594 correct 10 to 14
# index 81881 correct 29 to 30
# index 81895 correct 3 to 11
# index 81936 correct 7 to 9
# index 82191 correct 11 to 3
# index 82193 correct 11 to 3
# index 82237 correct 14 to 17
# index 82306 correct 30 to 38
# index 82359 correct 3 to 11
# index 82748 correct 7 to 11
# index 82810 correct 1 to 2
# index 83065 correct 10 to 13
# index 83079 correct 10 to 8
# index 83239 correct 33 to 34
# index 83295 correct 4 to 17
# index 83336 correct 19 to 20
# index 83449 correct 35 to 31
# index 83555 correct 4 to 12
# index 83707 correct 14 to 17
# index 83864 correct 4 to 11
# index 83880 correct 4 to 17
# index 84311 correct 9 to 4
# index 84336 correct 23 to 34
# index 84360 correct 5 to 1
# index 84372 correct 36 to 21
# index 84410 correct 30 to 29
# index 84448 correct 3 to 2
# index 84474 correct 1 to 0
# index 84965 correct 7 to 4
# index 85027 correct 38 to 35
# index 85132 correct 2 to 7
# index 85231 correct 4 to 7
# index 85314 correct 0 to 1
# index 85479 correct 3 to 8
# index 85843 correct 2 to 3
# index 85965 correct 35 to 31
# index 86057 correct 7 to 9
# index 86082 correct 28 to 30
# index 86111 correct 19 to 20
# index 86148 correct 4 to 3
# index 86323 correct 1 to 2
# index 86394 correct 29 to 33
# index 86585 correct 1 to 4
# index 86684 correct 2 to 1
# index 86771 correct 32 to 33
# index 86775 correct 32 to 33
# index 86835 correct 37 to 30
# index 86970 correct 1 to 38
# index 87028 correct 19 to 18
# index 87030 correct 19 to 18
# index 87040 correct 29 to 35
# index 87088 correct 38 to 31
# index 87186 correct 19 to 13
# index 87224 correct 1 to 17
# index 87299 correct 35 to 31
# index 88303 correct 0 to 5
# index 88463 correct 25 to 38
# index 88602 correct 1 to 4
# index 88920 correct 1 to 4
# index 88976 correct 17 to 1
# index 89047 correct 3 to 2
# index 89116 correct 7 to 11
# index 89122 correct 13 to 7
# index 89333 correct 8 to 2
# index 89382 correct 1 to 6
# index 89543 correct 11 to 3
# index 89783 correct 18 to 19
# index 89819 correct 4 to 2
# index 89823 correct 2 to 3
# index 89870 correct 14 to 17
# index 90067 correct 5 to 1
# index 90072 correct 5 to 1
# index 90105 correct 8 to 0
# index 90147 correct 2 to 1
# index 90348 correct 2 to 1
# index 90453 correct 38 to 18
# index 90587 correct 20 to 19
# index 91302 correct 38 to 3
# index 91336 correct 33 to 31
# index 91489 correct 31 to 35
# index 91753 correct 38 to 19
# index 91916 correct 1 to 3
# index 92071 correct 12 to 4
# index 92073 correct 2 to 4
# index 92161 correct 6 to 4
# index 92173 correct 17 to 2
# index 92297 correct 31 to 35
# index 92378 correct 38 to 19
# index 92490 correct 31 to 35
# index 92560 correct 30 to 38
# index 92647 correct 1 to 3
# index 92702 correct 12 to 4
# index 92742 correct 2 to 3
# index 92947 correct 26 to 13
# index 92960 correct 9 to 3
# index 92984 correct 18 to 38
# index 93019 correct 21 to 36
# index 93298 correct 6 to 12
# index 93451 correct 1 to 0
# index 93473 correct 11 to 7
# index 93481 correct 13 to 16
# index 93753 correct 1 to 38
# index 94112 correct 9 to 3
# index 94128 correct 3 to 2
# index 94195 correct 35 to 31
# index 94225 correct 3 to 2
# index 94230 correct 38 to 32
# index 94561 correct 3 to 9
# index 94749 correct 14 to 17
# index 94814 correct 19 to 3
# index 95010 correct 37 to 7
# index 95053 correct 35 to 21
# index 95092 correct 7 to 3
# index 95147 correct 1 to 8
# index 95306 correct 2 to 3
# index 95391 correct 5 to 0
# index 95411 correct 35 to 33
# index 95536 correct 2 to 3
# index 95625 correct 36 to 31
# index 95732 correct 11 to 2
# index 95830 correct 19 to 18
# index 95938 correct 32 to 33
# index 96621 correct 4 to 7
# index 96839 correct 21 to 35
# index 97407 correct 23 to 34
# index 97467 correct 2 to 3
# index 97716 correct 7 to 16
# index 97762 correct 4 to 7
# index 98303 correct 35 to 36
# index 98477 correct 38 to 34
# index 98492 correct 15 to 17
# index 98550 correct 20 to 19
# index 98685 correct 35 to 31
# index 98946 correct 15 to 38
# index 99366 correct 1 to 0
# index 99402 correct 30 to 27
# index 99516 correct 3 to 2
# index 99569 correct 0 to 1
# index 99657 correct 13 to 12
# index 99673 correct 14 to 17
# index 99808 correct 8 to 1
# index 99811 correct 2 to 1
# index 99813 correct 2 to 1
# index 99920 correct 11 to 3
# index 99926 correct 11 to 3
# index 100024 correct 1 to 4
# index 100055 correct 33 to 34
# index 100058 correct 33 to 34
# index 100188 correct 6 to 5
# index 100258 correct 31 to 35
# index 100459 correct 38 to 33
# index 100625 correct 0 to 10
# index 100751 correct 1 to 19
# index 100874 correct 35 to 31
# index 100879 correct 31 to 35
# index 101402 correct 1 to 0
# index 101485 correct 26 to 8
# index 102101 correct 33 to 35
# index 102107 correct 31 to 35
# index 102121 correct 15 to 0
# index 102364 correct 11 to 9
# index 102385 correct 18 to 19
# index 102454 correct 13 to 16
# index 102465 correct 16 to 18
# index 102471 correct 12 to 4
# index 102477 correct 12 to 7
# index 102553 correct 7 to 9
# index 102589 correct 11 to 3
# index 102762 correct 29 to 38
# index 102920 correct 35 to 31
# index 103211 correct 13 to 7
# index 103263 correct 0 to 8
# index 103569 correct 9 to 7
# index 103661 correct 19 to 18
# index 103770 correct 1 to 13
# index 103829 correct 17 to 7
# index 104046 correct 1 to 19
# index 104085 correct 9 to 3
# index 104550 correct 0 to 1
# index 104689 correct 4 to 3
# index 104783 correct 4 to 2
# index 104904 correct 28 to 38
# index 104907 correct 28 to 38
# index 104915 correct 17 to 14
# index 104971 correct 19 to 13
# index 104996 correct 11 to 7
# index 105022 correct 1 to 3
# index 105066 correct 5 to 0
# index 105080 correct 31 to 35
# index 105143 correct 34 to 38
# index 105147 correct 34 to 38
# index 105259 correct 20 to 38
# index 105430 correct 18 to 19
# index 105636 correct 30 to 29
# index 106146 correct 17 to 5
# index 106224 correct 32 to 23
# index 106302 correct 25 to 29
# index 106431 correct 11 to 3
# index 106558 correct 9 to 7
# index 106589 correct 2 to 3
# index 106683 correct 34 to 38
# index 107168 correct 31 to 35
# index 107246 correct 14 to 17
# index 107385 correct 4 to 2
# index 107447 correct 1 to 4
# index 107506 correct 18 to 19
# index 107511 correct 38 to 18
# index 107695 correct 2 to 3
# index 107699 correct 11 to 3
# index 107721 correct 1 to 0
# index 107782 correct 11 to 3
# index 107784 correct 11 to 3
# index 107804 correct 4 to 2
# index 107977 correct 38 to 33
# index 108010 correct 8 to 2
# index 108112 correct 32 to 19
# index 108121 correct 35 to 33
# index 108126 correct 9 to 4
# index 108291 correct 1 to 0
# index 108589 correct 5 to 1
# index 108642 correct 1 to 2
# index 108745 correct 1 to 17
# index 108810 correct 3 to 2
# index 109338 correct 7 to 3
# index 109379 correct 9 to 7
# index 109471 correct 31 to 35
# index 109609 correct 3 to 0
# index 109841 correct 23 to 37
# index 110030 correct 8 to 3
# index 110130 correct 5 to 13
# index 110152 correct 12 to 7
# index 110211 correct 22 to 21
# index 110551 correct 5 to 1
# index 110669 correct 30 to 37
# index 110934 correct 4 to 17
# index 111006 correct 4 to 38
# index 111165 correct 2 to 3
# index 111355 correct 31 to 35
# index 111408 correct 3 to 4
# index 112020 correct 38 to 36
# index 112516 correct 7 to 9
# index 112648 correct 4 to 2
# index 112661 correct 7 to 4
# index 112844 correct 19 to 20
# index 112862 correct 5 to 1
# index 113165 correct 15 to 0
# index 113204 correct 29 to 30
# index 113237 correct 31 to 35
# index 113246 correct 27 to 30
# index 113579 correct 4 to 13
# index 113963 correct 29 to 22
# index 114643 correct 17 to 14
# index 114695 correct 1 to 8
# index 114828 correct 31 to 32
# index 115192 correct 17 to 14
# index 115385 correct 31 to 35
# index 116010 correct 38 to 33
# index 116052 correct 8 to 2
# index 116074 correct 2 to 1
# index 116173 correct 38 to 35
# index 116800 correct 1 to 0
# index 116920 correct 2 to 1
# index 117136 correct 13 to 7
# index 117242 correct 0 to 8
# index 117278 correct 18 to 19
# index 117397 correct 7 to 4
# index 117478 correct 12 to 38
# index 117661 correct 20 to 19
# index 117790 correct 9 to 7
# index 118167 correct 31 to 35
# index 118341 correct 12 to 13
# index 118344 correct 12 to 13
# index 118583 correct 28 to 30
# index 118720 correct 10 to 1
# index 118739 correct 36 to 35
# index 119096 correct 1 to 0
# index 119315 correct 4 to 11
# index 119322 correct 11 to 4
# index 119324 correct 19 to 4
# index 119478 correct 24 to 23
# index 119663 correct 8 to 0
# index 119868 correct 11 to 7
# index 119942 correct 12 to 4
# index 120232 correct 9 to 2
# index 120376 correct 8 to 3
# index 120462 correct 4 to 13
# index 120468 correct 12 to 13
# index 120483 correct 3 to 2
# index 120722 correct 34 to 38
# index 120845 correct 31 to 35
# index 121077 correct 1 to 0
# index 121090 correct 38 to 19
# index 121433 correct 11 to 3
# index 121661 correct 2 to 3
# index 121954 correct 4 to 7
# index 121956 correct 4 to 7
# index 121977 correct 1 to 0
# index 122160 correct 9 to 7
# index 122185 correct 7 to 17
# index 122261 correct 7 to 4
# index 122494 correct 34 to 38
# index 122827 correct 9 to 8
# index 122853 correct 21 to 22
# index 122855 correct 21 to 22
# index 122895 correct 4 to 38
# index 122938 correct 31 to 35
# index 123127 correct 1 to 2
# index 123139 correct 21 to 36
# index 123244 correct 29 to 35
# index 123319 correct 0 to 1
# index 123530 correct 30 to 29
# index 123870 correct 3 to 2
# index 123888 correct 18 to 19
# index 123983 correct 1 to 4
# index 124089 correct 4 to 2
# index 124201 correct 2 to 4
# index 124236 correct 9 to 7
# index 124383 correct 38 to 35
# index 124584 correct 13 to 12
# index 124615 correct 30 to 38
# index 124780 correct 23 to 38
# index 124918 correct 38 to 26
# index 124989 correct 1 to 5
# index 125078 correct 30 to 38
# index 125258 correct 31 to 35
# index 125313 correct 4 to 14
# index 125690 correct 1 to 13
# index 125743 correct 8 to 2
# index 125936 correct 8 to 1
# index 125939 correct 2 to 1
# index 126143 correct 13 to 12
# index 126286 correct 3 to 9
# index 126417 correct 2 to 4
# index 126601 correct 1 to 2
# index 126622 correct 3 to 2
# index 126653 correct 8 to 1
# index 126748 correct 19 to 38
# index 127200 correct 33 to 32
# index 127451 correct 23 to 38
# index 127647 correct 10 to 2
# index 127682 correct 25 to 38
# index 127717 correct 13 to 7
# index 128136 correct 7 to 11
# index 128591 correct 19 to 20
# index 128987 correct 2 to 1
# index 128990 correct 2 to 1
# index 129263 correct 1 to 2
# index 129556 correct 2 to 3
# index 130191 correct 3 to 14
# index 130440 correct 31 to 35
# index 130584 correct 33 to 35
# index 130688 correct 38 to 7
# index 130785 correct 18 to 19
# index 130984 correct 17 to 14
# index 131490 correct 31 to 23
# index 131647 correct 4 to 9
# index 131706 correct 9 to 4
# index 131880 correct 2 to 3
# index 131900 correct 22 to 36
# index 132304 correct 29 to 38
# index 132394 correct 38 to 36
# index 132485 correct 17 to 1
# index 132830 correct 4 to 12
# index 132833 correct 13 to 12
# index 132947 correct 10 to 13
# index 132951 correct 4 to 7
# index 132979 correct 38 to 19
# index 133057 correct 4 to 13
# index 133118 correct 19 to 1
# index 133198 correct 0 to 8
# index 133208 correct 1 to 0
# index 133260 correct 1 to 13
# index 133280 correct 12 to 4
# index 133466 correct 38 to 32
# index 133793 correct 12 to 7
# index 133795 correct 12 to 7
# index 133807 correct 10 to 8
# index 134184 correct 26 to 4
# index 134338 correct 1 to 3
# index 134446 correct 38 to 37
# index 135512 correct 2 to 8
# index 135799 correct 7 to 12
# index 135940 correct 0 to 8
# index 136007 correct 38 to 14
# index 136014 correct 16 to 14
# index 136084 correct 9 to 8
# index 136268 correct 9 to 3
# index 136661 correct 12 to 7
# index 136668 correct 7 to 13
# index 136780 correct 10 to 13
# index 136783 correct 1 to 0
# index 136814 correct 17 to 14
# index 137092 correct 3 to 9
# index 137207 correct 12 to 4
# index 137280 correct 35 to 34
# index 137609 correct 9 to 7
# index 137746 correct 25 to 38
# index 138209 correct 16 to 13
# index 138559 correct 34 to 33
# index 138608 correct 27 to 30
# index 138637 correct 22 to 36
# index 138987 correct 16 to 4
# index 139215 correct 22 to 25
# index 139288 correct 1 to 17
# index 139983 correct 38 to 23
# index 140173 correct 29 to 30
# index 140237 correct 35 to 31
# index 140586 correct 1 to 10
# index 140841 correct 11 to 12
# index 140940 correct 2 to 1
# index 141103 correct 2 to 1
# index 141190 correct 13 to 12
# index 141200 correct 31 to 35
# index 141355 correct 1 to 8
# index 141624 correct 1 to 2
# index 141680 correct 0 to 1
# index 141793 correct 1 to 19
# index 141810 correct 33 to 34
# index 142822 correct 1 to 17
# index 142911 correct 4 to 3
# index 143349 correct 13 to 12
# index 143400 correct 1 to 0
# index 143436 correct 31 to 35
# index 143447 correct 8 to 2
# index 143449 correct 4 to 2
# index 143602 correct 29 to 38
# index 143791 correct 35 to 29
# index 144142 correct 8 to 2
# index 144168 correct 2 to 4
# index 144339 correct 12 to 13
# index 144438 correct 33 to 34
# index 144581 correct 31 to 35
# index 144600 correct 1 to 17
# index 144781 correct 2 to 3
# index 144833 correct 1 to 2
# index 145016 correct 2 to 17
# index 145020 correct 14 to 17
# index 145673 correct 38 to 34
# index 145822 correct 11 to 13
# index 145849 correct 2 to 4
# index 146007 correct 35 to 33
# index 146071 correct 7 to 9
# index 146207 correct 4 to 2
# index 146219 correct 38 to 37
# index 146364 correct 38 to 23
# index 146448 correct 13 to 38
# index 146590 correct 31 to 35
# index 146654 correct 1 to 17
# index 146662 correct 32 to 23
# index 147105 correct 2 to 1
# index 147208 correct 38 to 37
# index 147574 correct 2 to 8
# index 147829 correct 2 to 37
# index 148256 correct 4 to 10
# index 148749 correct 33 to 34
# index 149115 correct 12 to 3
# index 149126 correct 23 to 26
# index 149182 correct 13 to 12
# index 149261 correct 1 to 4
# index 149377 correct 1 to 0
# index 149388 correct 4 to 1
# index 149680 correct 13 to 9
# index 149900 correct 33 to 38
# index 150021 correct 35 to 21
# index 150425 correct 27 to 30
# index 150484 correct 29 to 38
# index 150501 correct 14 to 2
# index 150639 correct 2 to 3
# index 150716 correct 1 to 5
# index 151204 correct 2 to 1
# index 151362 correct 20 to 19
# index 151400 correct 2 to 11
# index 151425 correct 18 to 19
# index 151643 correct 2 to 9
# index 152136 correct 12 to 13
# index 152275 correct 4 to 12
# index 152538 correct 1 to 2
# index 152554 correct 35 to 29
# index 152647 correct 36 to 31
# index 152691 correct 2 to 1
# index 152831 correct 5 to 17
# index 152842 correct 31 to 35
# index 152920 correct 23 to 34
# index 153007 correct 1 to 38
# index 153019 correct 17 to 1
# index 153772 correct 29 to 35
# index 153984 correct 14 to 12
# index 154017 correct 1 to 17
# index 154232 correct 16 to 7
# index 154238 correct 14 to 7
# index 154624 correct 34 to 38
# index 154878 correct 35 to 31
# index 155023 correct 1 to 19
# index 155168 correct 2 to 3
# index 155251 correct 35 to 31
# index 155591 correct 29 to 35
# index 155680 correct 8 to 0
# index 155682 correct 8 to 0
# index 156048 correct 38 to 15
# index 156557 correct 12 to 13
# index 156576 correct 2 to 3
# index 156786 correct 4 to 1
# index 157092 correct 25 to 38
# index 157574 correct 21 to 35
# index 158004 correct 35 to 21
# index 158013 correct 19 to 38
# index 158558 correct 2 to 1
# index 158739 correct 29 to 38
# index 158946 correct 1 to 3
# index 159200 correct 2 to 8
# index 159704 correct 38 to 33
# index 159737 correct 35 to 36
# index 160244 correct 1 to 10
# index 160372 correct 21 to 22
# index 160394 correct 13 to 10
# index 160406 correct 38 to 19
# index 160724 correct 23 to 38
# index 160780 correct 13 to 10
# index 160846 correct 38 to 35
# index 160884 correct 17 to 2
# index 161023 correct 34 to 23
# index 161087 correct 35 to 31
# index 161461 correct 1 to 0
# index 162252 correct 1 to 4
# index 162414 correct 3 to 1
# index 162454 correct 32 to 38
# index 162484 correct 9 to 7
# index 162596 correct 8 to 0
# index 162619 correct 38 to 32
# index 163038 correct 2 to 9
# index 163239 correct 7 to 4
# index 163262 correct 31 to 35
# index 163306 correct 30 to 38
# index 163312 correct 14 to 7
# index 163320 correct 13 to 7
# index 163351 correct 7 to 17
# index 163354 correct 14 to 17
# index 163385 correct 22 to 31
# index 163519 correct 21 to 35
# index 163559 correct 8 to 3
# index 163732 correct 3 to 2
# index 163823 correct 14 to 17
# index 163937 correct 31 to 35
# index 164392 correct 5 to 16
# index 164655 correct 17 to 14
# index 165065 correct 1 to 0
# index 165318 correct 0 to 5
# index 165327 correct 35 to 29
# index 165329 correct 31 to 29
# index 165331 correct 38 to 29
# index 165408 correct 7 to 9
# index 165455 correct 22 to 36
# index 165464 correct 16 to 5
# index 165484 correct 35 to 36
# index 165500 correct 17 to 2
# index 165608 correct 3 to 9
# index 165819 correct 32 to 38
# index 166042 correct 18 to 19
# index 166118 correct 11 to 13
# index 166164 correct 1 to 3
# index 166171 correct 38 to 18
# index 166342 correct 1 to 4
# index 166774 correct 38 to 7
# index 167312 correct 0 to 3
# index 167372 correct 4 to 11
# index 167536 correct 2 to 3
# index 168359 correct 7 to 11
# index 168374 correct 16 to 7
# index 168409 correct 8 to 3
# index 168449 correct 15 to 0
# index 168745 correct 36 to 22
# index 168747 correct 36 to 22
# index 169685 correct 1 to 4
# index 169790 correct 4 to 1
# index 169917 correct 29 to 33
# index 169948 correct 15 to 0
# index 170005 correct 31 to 35
# index 170035 correct 8 to 1
# index 170193 correct 38 to 37
# index 170427 correct 38 to 30
# index 170713 correct 17 to 14
# index 170717 correct 17 to 8
# index 170880 correct 30 to 28
# index 170936 correct 1 to 4
# index 170957 correct 2 to 1
# index 171370 correct 35 to 36
# index 171492 correct 15 to 0
# index 171604 correct 38 to 33
# index 171612 correct 28 to 30
# index 171977 correct 6 to 12
# index 172379 correct 7 to 9
# index 172421 correct 4 to 1
# index 172499 correct 29 to 38
# index 172730 correct 7 to 11
# index 172851 correct 32 to 38
# index 172895 correct 21 to 29
# index 172898 correct 21 to 29
# index 173022 correct 30 to 29
# index 173122 correct 30 to 38
# index 173338 correct 2 to 12
# index 173407 correct 2 to 1
# index 173449 correct 4 to 23
# index 173847 correct 1 to 3
# index 174104 correct 32 to 38
# index 174165 correct 7 to 12
# index 174822 correct 13 to 12
# index 174860 correct 12 to 4
# index 175073 correct 30 to 38
# index 175141 correct 34 to 33
# index 175281 correct 2 to 11
# index 175297 correct 19 to 13
# index 175418 correct 9 to 8
# index 175960 correct 0 to 8
# index 175976 correct 29 to 38
# index 176189 correct 18 to 38
# index 176274 correct 2 to 1
# index 176373 correct 25 to 38
# index 176408 correct 32 to 38
# index 176679 correct 31 to 35
# index 176694 correct 8 to 1
# index 176720 correct 25 to 1
# index 177379 correct 9 to 3
# index 177533 correct 38 to 4
# index 177537 correct 38 to 12
# index 177558 correct 35 to 31
# index 177698 correct 38 to 13
# index 178557 correct 10 to 7
# index 178796 correct 37 to 38
# index 178928 correct 35 to 36
# index 179187 correct 26 to 38
# index 179495 correct 12 to 4
# index 179653 correct 9 to 3
# index 179824 correct 7 to 16
# index 180301 correct 1 to 0
# index 180432 correct 33 to 38
# index 180477 correct 4 to 1
# index 180508 correct 31 to 35
# index 180547 correct 13 to 9
# index 180591 correct 20 to 19
# index 180770 correct 1 to 0
# index 180798 correct 4 to 7
# index 180864 correct 14 to 17
# index 180927 correct 12 to 4
# index 180997 correct 3 to 8
# index 181046 correct 7 to 17
# index 181205 correct 31 to 35
# index 181253 correct 8 to 1
# index 181268 correct 35 to 33
# index 181474 correct 8 to 0
# index 181489 correct 22 to 21
# index 181554 correct 1 to 5
# index 181601 correct 4 to 1
# index 181619 correct 1 to 38
# index 181713 correct 33 to 35
# index 181716 correct 38 to 35
# index 181752 correct 4 to 7
# index 181770 correct 8 to 1
# index 181779 correct 29 to 30
# index 182693 correct 2 to 4
# index 182709 correct 32 to 38
# index 182774 correct 33 to 38
# index 182776 correct 34 to 38
# index 182814 correct 7 to 9
# index 183004 correct 31 to 35
# index 183082 correct 33 to 34
# index 183313 correct 2 to 17
# index 183332 correct 1 to 4
# index 183462 correct 9 to 38
# index 183900 correct 1 to 17
# index 183930 correct 2 to 3
# index 183962 correct 31 to 35
# index 183982 correct 17 to 14
# index 184280 correct 34 to 33
# index 184302 correct 16 to 5
# index 184476 correct 2 to 4
# index 184750 correct 31 to 35
# index 184935 correct 1 to 0
# index 185151 correct 29 to 33
# index 185162 correct 3 to 2
# index 185175 correct 12 to 13
# index 185493 correct 1 to 8
# index 185525 correct 32 to 38
# index 185527 correct 32 to 38
# index 185541 correct 4 to 13
# index 185599 correct 35 to 33
# index 185695 correct 35 to 31
# index 186608 correct 17 to 14
# index 186642 correct 2 to 3
# index 186737 correct 28 to 30
# index 186958 correct 4 to 12
# index 187073 correct 17 to 1
# index 187110 correct 38 to 36
# index 187367 correct 1 to 4
# index 187800 correct 8 to 0
# index 188127 correct 29 to 38
# index 188672 correct 1 to 37
# index 188903 correct 25 to 38
# index 188942 correct 4 to 1
# index 189487 correct 33 to 35
# index 189727 correct 20 to 19
# index 190415 correct 26 to 0
# index 190471 correct 7 to 10
# index 190577 correct 4 to 12
# index 190654 correct 32 to 14
# index 190863 correct 2 to 3
# index 191039 correct 26 to 32
# index 191122 correct 1 to 2
# index 191125 correct 4 to 2
# index 191338 correct 5 to 1
# index 191566 correct 38 to 29
# index 191578 correct 22 to 21
# index 191625 correct 21 to 35
# index 191628 correct 21 to 35
# index 191633 correct 2 to 4
# index 191635 correct 12 to 4
# index 191712 correct 9 to 4
# index 191716 correct 7 to 9
# index 191775 correct 1 to 5
# index 192104 correct 4 to 7
# index 192246 correct 21 to 22
# index 192798 correct 4 to 7
# index 192886 correct 38 to 33
# index 193228 correct 0 to 1
# index 193642 correct 28 to 37
# index 193691 correct 35 to 31
# index 193888 correct 6 to 12
# index 194424 correct 10 to 16
# index 194456 correct 4 to 29
# index 194576 correct 34 to 33
# index 194578 correct 34 to 33
# index 194597 correct 38 to 23
# index 194768 correct 38 to 35
# index 194771 correct 29 to 35
# index 194955 correct 19 to 20
# index 195111 correct 3 to 2
# index 195440 correct 1 to 0
# index 195560 correct 17 to 7
# index 195662 correct 13 to 9
# index 195803 correct 3 to 2
# index 196068 correct 7 to 11
# index 196070 correct 7 to 11
# index 196072 correct 7 to 11
# index 196160 correct 35 to 33
# index 196197 correct 29 to 30
# index 196443 correct 2 to 3
# index 196717 correct 19 to 20
# index 196795 correct 1 to 12
# index 196867 correct 9 to 7
# index 197558 correct 2 to 1
# index 197805 correct 38 to 32
# index 197807 correct 38 to 32
# index 197954 correct 5 to 0
# index 198106 correct 1 to 0
# index 198163 correct 2 to 4
# index 198170 correct 2 to 4
# index 198489 correct 0 to 15
# index 198496 correct 5 to 1
# index 198693 correct 18 to 19
# index 198695 correct 18 to 19
# index 198828 correct 4 to 2
# index 198836 correct 11 to 4
# index 198956 correct 4 to 12
# index 198958 correct 4 to 12
# index 198960 correct 13 to 12
# index 199137 correct 2 to 4
# index 199462 correct 3 to 8
# index 199618 correct 5 to 7
# index 199708 correct 35 to 31
# index 199724 correct 29 to 28
# index 199888 correct 1 to 0
# index 199894 correct 19 to 5
# index 200189 correct 1 to 0
# index 200260 correct 1 to 0
# index 200262 correct 1 to 0
# index 200374 correct 38 to 33
# index 200387 correct 7 to 3
# index 200454 correct 35 to 31
# index 200464 correct 31 to 35
# index 200748 correct 9 to 3
# index 200769 correct 25 to 29
# index 200816 correct 14 to 17
# index 200819 correct 14 to 17
# index 200825 correct 17 to 5
# index 200832 correct 12 to 13
# index 200982 correct 12 to 2
# index 201091 correct 14 to 17
# index 201149 correct 7 to 4
# index 201291 correct 8 to 0
# index 201358 correct 6 to 1
# index 201424 correct 35 to 31
# index 201453 correct 4 to 13
# index 201501 correct 21 to 29
# index 201504 correct 21 to 29
# index 201596 correct 14 to 8
# index 201598 correct 1 to 8
# index 201749 correct 16 to 10
# index 201783 correct 8 to 9
# index 201805 correct 4 to 3
# index 201834 correct 13 to 16
# index 201931 correct 29 to 31
# index 201979 correct 33 to 38
# index 201994 correct 9 to 3
# index 202013 correct 4 to 3
# index 202302 correct 20 to 19
# index 202373 correct 9 to 7
# index 202783 correct 9 to 7
# index 202859 correct 5 to 0
# index 202936 correct 2 to 1
# index 203196 correct 0 to 1
# index 203247 correct 13 to 12
# index 203315 correct 2 to 11
# index 203533 correct 38 to 17
# index 203581 correct 25 to 30
# index 203584 correct 38 to 30
# index 203707 correct 2 to 1
# index 203777 correct 20 to 13
# index 203802 correct 38 to 30
# index 204022 correct 19 to 20
# index 204607 correct 19 to 18
# index 204638 correct 13 to 7
# index 204728 correct 18 to 19
# index 204881 correct 29 to 35
# index 204984 correct 1 to 17
# index 205037 correct 17 to 5
# index 205611 correct 19 to 38
# index 205692 correct 38 to 3
# index 205796 correct 18 to 19
# index 206038 correct 11 to 13
# index 206165 correct 4 to 2
# index 206273 correct 19 to 37
# index 206408 correct 5 to 0
# index 206416 correct 30 to 38
# index 206481 correct 25 to 38
# index 206494 correct 18 to 19
# index 206787 correct 36 to 21
# index 206806 correct 19 to 18
# index 206889 correct 32 to 38
# index 207024 correct 4 to 7
# index 207065 correct 2 to 3
# index 207072 correct 27 to 38
# index 207105 correct 12 to 13
# index 207137 correct 31 to 35
# index 207403 correct 19 to 38
# index 207525 correct 19 to 13
# index 207822 correct 4 to 13
# index 207970 correct 1 to 0
# index 208075 correct 2 to 3
# index 208672 correct 22 to 21
# index 208717 correct 4 to 2
# index 208719 correct 4 to 2
# index 208738 correct 9 to 7
# index 208747 correct 10 to 9
# index 208776 correct 14 to 17
# index 208892 correct 2 to 1
# index 208902 correct 31 to 35
# index 209025 correct 9 to 7
# index 209118 correct 7 to 3
# index 209225 correct 37 to 29
# index 209263 correct 14 to 5
# index 209744 correct 18 to 19
# index 209817 correct 2 to 1
# index 209908 correct 31 to 35
# index 210493 correct 4 to 1
# index 210572 correct 38 to 37
# index 210896 correct 4 to 5
# index 210898 correct 6 to 5
# index 210963 correct 6 to 5
# index 211087 correct 9 to 7
# index 211089 correct 9 to 7
# index 211168 correct 37 to 38
# index 211273 correct 4 to 12
# index 211502 correct 4 to 19
# index 211749 correct 8 to 9
# index 211899 correct 21 to 22
# index 211906 correct 38 to 23
# index 212024 correct 8 to 10
# index 212131 correct 14 to 17
# index 212175 correct 1 to 8
# index 212186 correct 29 to 34
# index 212512 correct 4 to 13
# index 213008 correct 17 to 3
# index 213199 correct 3 to 8
# index 213368 correct 1 to 12
# index 213398 correct 2 to 1
# index 213485 correct 35 to 31
# index 213621 correct 15 to 37
# index 213966 correct 14 to 17
# index 214005 correct 29 to 34
# index 214042 correct 30 to 29
# index 214205 correct 32 to 38
# index 214304 correct 38 to 23
# index 214447 correct 2 to 1
# index 214503 correct 3 to 9
# index 214558 correct 5 to 0
# index 214594 correct 1 to 2
# index 214613 correct 1 to 17
# index 214686 correct 35 to 36
# index 214697 correct 21 to 29
# index 215478 correct 29 to 38
# index 215626 correct 1 to 17
# index 215982 correct 34 to 33
# index 216095 correct 38 to 32
# index 216123 correct 0 to 35
# index 216171 correct 3 to 9
# index 216483 correct 1 to 3
# index 216769 correct 12 to 5
# index 216951 correct 7 to 17
# index 217059 correct 35 to 31
# index 217081 correct 7 to 9
# index 217208 correct 7 to 9
# index 217305 correct 2 to 3
# index 217307 correct 2 to 3
# index 217864 correct 23 to 38
# index 217905 correct 1 to 4
# index 218010 correct 1 to 4
# index 218080 correct 0 to 8
# index 218132 correct 1 to 2
# index 218200 correct 4 to 7
# index 218273 correct 1 to 0
# index 218504 correct 21 to 22
# index 218507 correct 21 to 22
# index 218584 correct 18 to 5
# index 218700 correct 1 to 15
# index 218796 correct 3 to 7
# index 219169 correct 37 to 38
# index 219220 correct 31 to 35
# index 219226 correct 23 to 34
# index 219274 correct 7 to 9
# index 219382 correct 32 to 38
# index 219385 correct 19 to 38
# index 219434 correct 3 to 0
# index 219751 correct 16 to 10
# index 219888 correct 35 to 31
# index 219901 correct 3 to 4
# index 219938 correct 3 to 2
# index 220172 correct 1 to 0
# index 220504 correct 14 to 17
# index 220664 correct 1 to 19
# index 221791 correct 23 to 38
# index 221831 correct 3 to 11
# index 222114 correct 0 to 1
# index 222220 correct 19 to 20
# index 222305 correct 21 to 36
# index 222339 correct 11 to 3
# index 222393 correct 8 to 0
# index 222569 correct 38 to 33
# index 222750 correct 4 to 9
# index 222775 correct 31 to 35
# index 222875 correct 33 to 37
# index 223166 correct 23 to 32
# index 223310 correct 13 to 12
# index 223357 correct 4 to 12
# index 223387 correct 12 to 4
# index 223444 correct 2 to 1
# index 223453 correct 23 to 31
# index 223471 correct 9 to 7
# index 223585 correct 1 to 4
# index 223588 correct 1 to 2
# index 223624 correct 1 to 2
# index 224046 correct 35 to 29
# index 224227 correct 23 to 38
# index 224284 correct 3 to 11
# index 224322 correct 3 to 2
# index 224377 correct 1 to 2
# index 224469 correct 18 to 19
# index 224704 correct 38 to 33
# index 224768 correct 2 to 8
# index 225088 correct 35 to 29
# index 225171 correct 25 to 27
# index 225184 correct 14 to 8
# index 225332 correct 1 to 4
# index 225377 correct 4 to 2
# index 225605 correct 12 to 7
# index 225893 correct 4 to 12
# index 225913 correct 2 to 3
# index 226168 correct 19 to 18
# index 226191 correct 17 to 14
# index 226239 correct 33 to 38
# index 226246 correct 13 to 10
# index 226479 correct 38 to 3
# index 226587 correct 30 to 29
# index 227565 correct 38 to 35
# index 227652 correct 1 to 4
# index 227967 correct 12 to 17
# index 228116 correct 12 to 13
# index 228447 correct 7 to 4
# index 228471 correct 5 to 0
# index 228483 correct 35 to 31
# index 228495 correct 1 to 0
# index 228508 correct 14 to 17
# index 228695 correct 32 to 38
# index 228760 correct 15 to 0
# index 228794 correct 33 to 38
# index 228801 correct 9 to 4
# index 228982 correct 2 to 3
# index 229047 correct 34 to 38
# index 229541 correct 19 to 1
# index 230037 correct 23 to 38
# index 230094 correct 7 to 9
# index 230147 correct 1 to 0
# index 230300 correct 7 to 4
# index 230502 correct 31 to 35
# index 231043 correct 38 to 36
# index 231151 correct 32 to 38
# index 231226 correct 1 to 2
# index 231311 correct 4 to 13
# index 231351 correct 38 to 1
# index 231726 correct 29 to 35
# index 231797 correct 1 to 4
# index 232446 correct 29 to 38
# index 232679 correct 25 to 38
# index 233023 correct 12 to 10
# index 233080 correct 7 to 16
# index 233150 correct 21 to 22
# index 233183 correct 1 to 0
# index 233291 correct 33 to 38
# index 233370 correct 17 to 14
# index 233388 correct 4 to 13
# index 233642 correct 38 to 19
# index 233701 correct 8 to 0
# index 234058 correct 37 to 1
# index 234184 correct 1 to 19
# index 234237 correct 34 to 29
# index 235102 correct 38 to 34
# index 235177 correct 2 to 17
# index 235195 correct 12 to 7
# index 235306 correct 23 to 34
# index 235573 correct 17 to 2
# index 235627 correct 1 to 4
# index 235806 correct 1 to 4
# index 235864 correct 9 to 3
# index 236047 correct 10 to 7
# index 236167 correct 1 to 0
# index 236184 correct 1 to 2
# index 236318 correct 17 to 4
# index 236344 correct 32 to 38
# index 236583 correct 18 to 19
# index 236587 correct 18 to 19
# index 236749 correct 2 to 3
# index 236752 correct 2 to 3
# index 237036 correct 38 to 35
# index 237067 correct 30 to 38
# index 237539 correct 4 to 2
# index 237678 correct 2 to 17
# index 237905 correct 31 to 35
# index 238138 correct 31 to 35
# index 238154 correct 17 to 4
# index 238255 correct 30 to 38
# index 238385 correct 1 to 17
# index 238402 correct 28 to 37
# index 238440 correct 26 to 19
# index 238846 correct 5 to 1
# index 238869 correct 12 to 2
# index 238873 correct 12 to 2
# index 238891 correct 19 to 20
# index 238937 correct 34 to 35
# index 239000 correct 23 to 38
# index 239037 correct 3 to 11
# index 239039 correct 3 to 11
# index 239055 correct 8 to 1
# index 239062 correct 1 to 0
# index 239119 correct 20 to 19
# index 239122 correct 20 to 19
# index 239231 correct 38 to 19
# index 239260 correct 32 to 38
# index 239401 correct 8 to 3
# index 239641 correct 12 to 1
# index 240078 correct 7 to 9
# index 240584 correct 10 to 7
# index 240766 correct 7 to 9
# index 240800 correct 1 to 5
# index 240926 correct 5 to 1
# index 240999 correct 5 to 0
# index 241068 correct 2 to 3
# index 241213 correct 7 to 11
# index 241258 correct 13 to 16
# index 241591 correct 9 to 4
# index 241788 correct 11 to 3
# index 241795 correct 9 to 12
# index 242101 correct 2 to 1
# index 242280 correct 8 to 17
# index 242335 correct 5 to 12
# index 242581 correct 8 to 2
# index 242813 correct 2 to 3
# index 243194 correct 17 to 14
# index 243315 correct 33 to 38
# index 244174 correct 15 to 0
# index 244254 correct 9 to 4
# index 244516 correct 5 to 1
# index 246048 correct 35 to 31
# index 246073 correct 2 to 4
# index 246103 correct 12 to 13
# index 246155 correct 31 to 35
# index 246369 correct 0 to 8
# index 246372 correct 0 to 8
# index 246534 correct 1 to 17
# index 246752 correct 1 to 0
# index 246882 correct 11 to 2
# index 246888 correct 18 to 11
# index 246974 correct 11 to 3
# index 247006 correct 22 to 36
# index 247198 correct 2 to 1
# index 247863 correct 28 to 33
# index 247902 correct 8 to 0
# index 247974 correct 4 to 12
# index 248152 correct 34 to 23
# index 248244 correct 31 to 35
# index 248655 correct 14 to 17
# index 248764 correct 21 to 29
# index 249004 correct 5 to 8
# index 249133 correct 7 to 12
# index 249200 correct 17 to 2
# index 249211 correct 1 to 0
# index 249242 correct 7 to 3
# index 249543 correct 4 to 7
# index 249562 correct 19 to 38
# index 249793 correct 2 to 17
# index 250023 correct 17 to 14
# index 250505 correct 0 to 17
# index 250527 correct 19 to 18
# index 250561 correct 3 to 8
# index 250618 correct 9 to 7
# index 250791 correct 4 to 13
# index 250983 correct 2 to 10
# index 251137 correct 36 to 35
# index 251166 correct 13 to 12
# index 251340 correct 34 to 38
# index 251457 correct 29 to 33
# index 251641 correct 19 to 3
# index 251646 correct 1 to 2
# index 251728 correct 18 to 19
# index 252296 correct 30 to 29
# index 252301 correct 5 to 1
# index 252357 correct 2 to 1
# index 252479 correct 0 to 1
# index 252482 correct 8 to 1
# index 252612 correct 2 to 9
# index 252703 correct 0 to 1
# index 252734 correct 8 to 0
# index 252745 correct 25 to 29
# index 252841 correct 7 to 10
# index 252883 correct 9 to 4
# index 253131 correct 38 to 29
# index 253270 correct 1 to 8
# index 253343 correct 32 to 38
# index 253379 correct 13 to 16
# index 253587 correct 25 to 38
# index 253591 correct 33 to 38
# index 253611 correct 31 to 35
# index 253666 correct 26 to 14
# index 253716 correct 22 to 29
# index 253942 correct 35 to 31
# index 253998 correct 26 to 38
# index 254016 correct 21 to 22
# index 254936 correct 3 to 9
# index 255026 correct 13 to 10
# index 255073 correct 9 to 4
# index 255091 correct 2 to 1
# index 255218 correct 1 to 8
# index 255257 correct 19 to 17
# index 255492 correct 3 to 11
# index 255599 correct 13 to 19
# index 255844 correct 2 to 8
# index 255983 correct 37 to 32
# index 256131 correct 30 to 38
# index 256402 correct 9 to 8
# index 256416 correct 36 to 21
# index 256484 correct 19 to 18
# index 256511 correct 22 to 35
# index 256753 correct 18 to 5
# index 257356 correct 11 to 13
# index 257393 correct 1 to 19
# index 257498 correct 29 to 28
# index 257610 correct 13 to 11
# index 257612 correct 13 to 11
# index 257657 correct 3 to 9
# index 257917 correct 1 to 5
# index 258130 correct 30 to 37
# index 258315 correct 37 to 30
# index 258636 correct 35 to 33
# index 258932 correct 1 to 17
# index 258979 correct 19 to 32
# index 259027 correct 2 to 1
# index 259281 correct 1 to 13
# index 259302 correct 5 to 0
# index 259382 correct 1 to 19
# index 259494 correct 29 to 38
# index 260091 correct 4 to 2
# index 260231 correct 38 to 15
# index 260233 correct 37 to 15
# index 260492 correct 4 to 2
# index 260846 correct 16 to 13
# index 261064 correct 9 to 8
# index 261102 correct 17 to 14
# index 261182 correct 34 to 29
# index 261488 correct 10 to 7
# index 261831 correct 20 to 19
# index 262303 correct 3 to 2
# index 262518 correct 17 to 2
# index 262536 correct 4 to 7
# index 262773 correct 1 to 8
# index 262828 correct 28 to 29
# index 262872 correct 31 to 35
# index 262881 correct 1 to 15
# index 262949 correct 36 to 21
# index 263049 correct 11 to 3
# index 263713 correct 31 to 34
# index 263832 correct 19 to 7
# index 263975 correct 7 to 3
# index 264180 correct 32 to 38
# index 264188 correct 29 to 21
# index 264278 correct 4 to 11
# index 264327 correct 11 to 3
# index 264344 correct 34 to 38
# index 264359 correct 0 to 5
# index 264376 correct 25 to 1
# index 264480 correct 1 to 5
# index 264910 correct 23 to 26
# index 265072 correct 34 to 37
# index 265597 correct 2 to 12
# index 265670 correct 9 to 7
# index 265684 correct 31 to 35
# index 265784 correct 0 to 1
# index 265812 correct 1 to 17
# index 265980 correct 2 to 1
# index 265994 correct 22 to 29
# index 266243 correct 34 to 33
# index 266295 correct 19 to 5
# index 266310 correct 35 to 31
# index 266356 correct 35 to 31
# index 266566 correct 1 to 17
# index 266934 correct 13 to 4
# index 267603 correct 8 to 3
# index 267849 correct 4 to 7
# index 268071 correct 14 to 17
# index 268233 correct 2 to 1
# index 268542 correct 14 to 17
# index 268865 correct 35 to 31
# index 269030 correct 3 to 1
# index 269165 correct 13 to 11
# index 269385 correct 6 to 1
# index 269820 correct 9 to 7
# index 269964 correct 38 to 35
# index 270153 correct 1 to 4
# index 270254 correct 3 to 9
# index 270324 correct 1 to 8
# index 270597 correct 25 to 38
# index 270605 correct 4 to 12
# index 270866 correct 2 to 4
# index 271064 correct 8 to 0
# index 271155 correct 31 to 35
# index 271211 correct 19 to 7
# index 271349 correct 3 to 8
# index 271586 correct 11 to 4
# index 271591 correct 4 to 11
# index 271600 correct 34 to 23
# index 271645 correct 32 to 38
# index 271672 correct 31 to 35
# index 271741 correct 35 to 31
# index 271908 correct 22 to 21
# index 272281 correct 20 to 19
# index 272648 correct 30 to 38
# index 272706 correct 4 to 12
# index 272710 correct 13 to 12
# index 272893 correct 2 to 1
# index 273233 correct 31 to 35
# index 273704 correct 13 to 10
# index 273822 correct 7 to 11
# index 273837 correct 0 to 1
# index 273860 correct 8 to 0
# index 274187 correct 38 to 14
# index 274261 correct 9 to 7
# index 274435 correct 33 to 38
# index 274708 correct 2 to 1
# index 274883 correct 15 to 0
# index 274987 correct 13 to 10
# index 275093 correct 1 to 0
# index 275215 correct 3 to 2
# index 275237 correct 38 to 32
# index 275252 correct 1 to 5
# index 275427 correct 38 to 7
# index 275429 correct 28 to 7
# index 275438 correct 8 to 9
# index 275545 correct 38 to 32
# index 275556 correct 9 to 7
# index 275630 correct 11 to 4
# index 275639 correct 4 to 7
# index 275722 correct 7 to 9
# index 275725 correct 7 to 9
# index 275855 correct 35 to 31
# index 275946 correct 2 to 3
# index 276008 correct 13 to 19
# index 276072 correct 1 to 5
# index 276124 correct 31 to 35
# index 276129 correct 35 to 31
# index 276158 correct 3 to 11
# index 276218 correct 9 to 7
# index 276280 correct 0 to 8
# index 276412 correct 1 to 2
# index 276448 correct 1 to 2
# index 276964 correct 19 to 38
# index 276991 correct 2 to 1
# index 277137 correct 23 to 32
# index 277254 correct 13 to 7
# index 277260 correct 4 to 7
# index 277546 correct 35 to 33
# index 277821 correct 4 to 17
# index 277868 correct 9 to 7
# index 277870 correct 9 to 7
# index 277922 correct 12 to 4
# index 277924 correct 1 to 4
# index 277965 correct 4 to 9
# index 277994 correct 9 to 7
# index 278169 correct 1 to 4
# index 278509 correct 18 to 19
# index 278552 correct 2 to 1
# index 278710 correct 2 to 11
# index 278767 correct 7 to 4
# index 278772 correct 7 to 4
# index 278838 correct 0 to 1
# index 280002 correct 18 to 38
# index 280075 correct 18 to 19
# index 280119 correct 1 to 2
# index 280160 correct 14 to 3
# index 280196 correct 38 to 34
# index 280301 correct 34 to 33
# index 280618 correct 33 to 38
# index 280821 correct 18 to 19
# index 280843 correct 13 to 11
# index 280864 correct 9 to 8
# index 280950 correct 7 to 4
# index 281179 correct 4 to 7
# index 281253 correct 35 to 31
# index 281286 correct 35 to 31
# index 281380 correct 31 to 35
# index 281509 correct 12 to 13
# index 281603 correct 1 to 5
# index 281809 correct 29 to 38
# index 282039 correct 11 to 3
# index 282639 correct 37 to 19
# index 282862 correct 3 to 2
# index 283168 correct 1 to 4
# index 283187 correct 9 to 7
# index 283196 correct 4 to 1
# index 283273 correct 1 to 4
# index 283344 correct 18 to 19
# index 283411 correct 19 to 38
# index 283447 correct 1 to 38
# index 283482 correct 35 to 31
# index 283614 correct 19 to 20
# index 283701 correct 1 to 2
# index 284206 correct 31 to 35
# index 284222 correct 2 to 1
# index 284268 correct 35 to 36
# index 284298 correct 3 to 2
# index 284420 correct 30 to 29
# index 284425 correct 16 to 9
# index 284935 correct 9 to 13
# index 284994 correct 1 to 2
# index 285141 correct 1 to 8
# index 285191 correct 8 to 5
# index 285201 correct 8 to 1
# index 285211 correct 31 to 35
# index 285300 correct 35 to 33
# index 285357 correct 2 to 4
# index 285456 correct 30 to 37
# index 285570 correct 35 to 31
# index 285726 correct 4 to 7
# index 285945 correct 31 to 35
# index 285953 correct 35 to 31
# index 286158 correct 38 to 33
# index 286268 correct 16 to 13
# index 286449 correct 2 to 8
# index 286697 correct 19 to 1
# index 286737 correct 34 to 31
# index 287182 correct 38 to 16
# index 287422 correct 9 to 3
# index 287591 correct 14 to 17
# index 287747 correct 9 to 7
# index 287940 correct 18 to 16
# index 287987 correct 4 to 1
# index 288003 correct 7 to 9
# index 288011 correct 19 to 38
# index 288041 correct 1 to 14
# index 288044 correct 26 to 0
# index 288046 correct 1 to 0
# index 288050 correct 8 to 0
# index 288624 correct 6 to 1
# index 288929 correct 34 to 38
# index 289849 correct 9 to 7
# index 289862 correct 9 to 7
# index 289994 correct 10 to 8
# index 290206 correct 31 to 35
# index 290209 correct 4 to 1
# index 290306 correct 32 to 38
# index 290368 correct 29 to 38
# index 290901 correct 7 to 10
# index 290958 correct 7 to 3
# index 291108 correct 34 to 38
# index 291138 correct 1 to 17
# index 291140 correct 1 to 17
# index 291154 correct 35 to 31
# index 291913 correct 15 to 2
# index 292303 correct 8 to 1
# index 292305 correct 8 to 1
# index 292307 correct 8 to 1
# index 292361 correct 19 to 18
# index 292471 correct 38 to 3
# index 292630 correct 12 to 7
# index 292763 correct 35 to 36
# index 292916 correct 27 to 38
# index 293247 correct 5 to 1
# index 293360 correct 1 to 0
# index 293845 correct 18 to 38
# index 293935 correct 35 to 29
# index 294135 correct 21 to 36
# index 294189 correct 35 to 36
# index 294229 correct 22 to 15
# index 294505 correct 26 to 0
# index 294659 correct 13 to 3
# index 294723 correct 38 to 5
# index 294752 correct 1 to 5
# index 294816 correct 11 to 9
# index 294869 correct 38 to 37
# index 294922 correct 8 to 9
# index 295040 correct 24 to 28
# index 295074 correct 13 to 4
# index 295137 correct 8 to 0
# index 295225 correct 12 to 13
# index 295231 correct 4 to 13
# index 295593 correct 4 to 2
# index 295624 correct 9 to 7
# index 295921 correct 8 to 2
# index 295930 correct 26 to 8
# index 295953 correct 3 to 9
# index 296248 correct 4 to 3
# index 296381 correct 34 to 29
# index 296397 correct 27 to 38
# index 296418 correct 29 to 34
# index 296423 correct 23 to 34
# index 296500 correct 36 to 31
# index 296544 correct 7 to 9
# index 296561 correct 22 to 25
# index 296573 correct 12 to 4
# index 296841 correct 5 to 16
# index 296957 correct 3 to 19
# index 297106 correct 27 to 38
# index 297149 correct 32 to 3
# index 297195 correct 31 to 36
# index 297325 correct 13 to 12
# index 297438 correct 13 to 38
# index 297491 correct 30 to 29
# index 297724 correct 36 to 33
# index 297742 correct 13 to 7
# index 297943 correct 26 to 19
# index 297996 correct 31 to 38
# index 297999 correct 22 to 25
# index 298073 correct 1 to 8
# index 298097 correct 21 to 29
# index 298319 correct 35 to 31
# index 298381 correct 23 to 38
# index 298491 correct 7 to 9
# index 298545 correct 4 to 7
# index 298617 correct 20 to 19
# index 298692 correct 5 to 16
# index 298700 correct 1 to 4
# index 298811 correct 5 to 17
# index 298821 correct 35 to 31
# index 298858 correct 15 to 0
# index 299090 correct 12 to 13
# index 299158 correct 29 to 22
# index 299180 correct 22 to 21
# index 299196 correct 2 to 1
# index 299295 correct 31 to 38
# index 299617 correct 1 to 8
# index 299862 correct 4 to 2
# index 299903 correct 4 to 1
# index 300033 correct 2 to 9
# index 300130 correct 23 to 31
# index 300144 correct 8 to 2
# index 300224 correct 1 to 8
# index 300238 correct 31 to 35
# index 300532 correct 19 to 38
# index 300724 correct 12 to 4
# index 300728 correct 4 to 17
# index 300786 correct 7 to 2
# index 300861 correct 4 to 7
# index 300937 correct 35 to 36
# index 300963 correct 35 to 31
# index 301134 correct 4 to 13
# index 301145 correct 4 to 1
# index 301341 correct 13 to 12
# index 301449 correct 4 to 1
# index 301542 correct 1 to 17
# index 301864 correct 29 to 38
# index 302166 correct 5 to 1
# index 302229 correct 10 to 16
# index 302365 correct 7 to 9
# index 302452 correct 8 to 0
# index 302464 correct 38 to 0
# index 302485 correct 2 to 1
# index 302874 correct 38 to 37
# index 302895 correct 13 to 12
# index 302940 correct 4 to 13
# index 302992 correct 38 to 33
# index 303019 correct 7 to 9
# index 303125 correct 38 to 35
# index 303240 correct 12 to 13
# index 303589 correct 15 to 1
# index 303595 correct 17 to 14
# index 303695 correct 37 to 38
# index 304716 correct 3 to 2
# index 304780 correct 34 to 38
# index 304887 correct 4 to 7
# index 305438 correct 8 to 37
# index 305478 correct 13 to 7
# index 305522 correct 4 to 7
# index 305584 correct 1 to 4
# index 305655 correct 36 to 35
# index 305657 correct 36 to 35
# index 305929 correct 35 to 31
# index 306084 correct 36 to 21
# index 306092 correct 1 to 4
# index 306146 correct 32 to 18
# index 306288 correct 2 to 17
# index 306446 correct 38 to 34
# index 306596 correct 20 to 19
# index 307256 correct 5 to 1
# index 307323 correct 1 to 6
# correction: 2102, precentage: 0.007

# %% [markdown]
# Write prediction to a CSV file.
#
# After finish running this block, download the file `prediction.csv` from the files section on the left-hand side and submit it to Kaggle.

# %%
# !mkdir -p 'result'
with open('result/prediction.csv', 'w') as f:
    f.write('Id,Class\n')
    for i, y in enumerate(predict):
        f.write('{},{}\n'.format(i, y))
# !zip -r 'result/prediction.zip' 'result/prediction.csv'
# Out:
#   adding: result/prediction.csv (deflated 72%)
